# %% [markdown]
# # [한글 감성 분석 실습: 한글 전처리 및 TDM & TFIDF]

# %% [markdown]
# ### jupyter notebook 단축키
#
# - ctrl+enter: 셀 실행
# - shift+enter: 셀 실행 및 다음 셀 이동
# - alt+enter: 셀 실행, 다음 셀 이동, 새로운 셀 생성
# - a: 상단에 새로운 셀 만들기
# - b: 하단에 새로운 셀 만들기
# - dd: 셀 삭제(x: 셀 삭제)
# - y: Code로 변경
# - m: Markdown으로 변경

# %% [markdown]
# ## 1. 모듈 불러오기
#
# #### import '불러올 패키지명' as '그 패키지를 파이썬에서 사용할 이름'

# %%
import konlpy
from konlpy.tag import Hannanum, Kkma, Komoran

import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import accuracy_score
from gensim.models.doc2vec import Doc2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize
import nltk

import re
import sys
import os
import time
import random
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. 데이터 불러오기: English Movie Review Data
#
# #### 데이터 구조
# - 데이터: 한글 영화 리뷰 데이터
# - 관측치 건수: 13697건 (train: 12997 / test: 700)
# - 변수 개수: 설명변수 1개 / 반응변수 1개
#
# #### 설명 변수(원인: 예측값을 설명할 수 있는 변수)
# - review: 영화 리뷰 데이터(Document)
#
#
# #### 반응 변수(결과: 예측하고자 하는 값)
# - sentiment: 리뷰의 감정 (긍정:1/ 부정:0)

# %%
train_data = pd.read_csv('data/korean_train.csv',encoding='utf-8', engine='python', index_col=0)
test_data = pd.read_csv('data/korean_test.csv', encoding='utf-8', engine='python',index_col=0)

# %% [markdown]
# ## 3. 데이터 구성

# %% [markdown]
# ### - 3.1 train 데이터 및 test 데이터 갯수 확인

# %%
print('DATA COLUMNS NAMES: {}'.format(list(train_data.columns)))
print('\n')
print('TRAIN DATA SHAPE: {}'.format(train_data.shape))
print('TEST  DATA SHAPE: {}'.format(test_data.shape))
# Out:
# DATA COLUMNS NAMES: ['reviews', 'sentiment']
#
#
# TRAIN DATA SHAPE: (12997, 2)
# TEST  DATA SHAPE: (700, 2)

# %% [markdown]
# ### - 3.2 train/test 데이터 병합

# %%
whole_data = pd.concat([train_data, test_data]).reset_index(drop=True)

# %%
whole_data.head() #.head(): 상위 5개 예시
# Out:
#                                              reviews  sentiment
# 0                                아 더빙.. 진짜 짜증나네요 목소리          0
# 1                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나          1
# 2                                  너무재밓었다그래서보는것을추천한다          0
# 3                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정          0
# 4  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...          1

# %% [markdown]
# ## 4. 데이터 텍스트 전처리

# %% [markdown]
# ### - 4.1 데이터 기호 및 문법 정규화
#
# https://python.bakyeono.net/chapter-11-2.html
#
# #### re모듈은 패턴과 매치하는 텍스트를 찾고 조각하는 기능 제공
#
# - re.compile(pattern)            : 패턴 문자열 pattern을 패턴 객체로 컴파일한다.
# - re.search(pattern, string)     : string에서 pattern과 매치하는 텍스트를 탐색한다. (임의 지점 매치)
# - re.match(pattern, string)      : string에서 pattern과 매치하는 텍스트를 탐색한다. (시작점 매치)
# - re.fullmatch(pattern, string)  : string에서 pattern과 매치하는 텍스트를 탐색한다. (전체 매치)
# - re.sub(pattern, replacd, string)  : string에서 pattern과 매치하는 텍스트를 repl로 치환한다.
# - re.split(pattern, string)	     : string을 pattern을 기준으로 나눈다.

# %%
# re.sub(pattern, replacd, string) example
re.sub("-","0","991225-1234567")
# Out:
# '99122501234567'

# %%
docs_tr = [re.sub(r"\%\$ ?\([^)]+\)-", "", x) for x in whole_data.reviews.values.tolist()]
docs_tr = [re.sub("\'", " ", x) for x in docs_tr]
docs_tr = [re.sub('\S*@\S*\s?', '', x) for x in docs_tr]
docs_tr = [re.sub('\s+', ' ', x) for x in docs_tr]
docs_tr = [re.sub('[^\w\s]','',x) for x in docs_tr]

# %%
# Original data
pd.DataFrame(whole_data.reviews.head())
# Out:
#                                              reviews
# 0                                아 더빙.. 진짜 짜증나네요 목소리
# 1                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나
# 2                                  너무재밓었다그래서보는것을추천한다
# 3                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정
# 4  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...

# %%
# Preprocessed data (Normalization)
pd.DataFrame(docs_tr, columns = ['preprocessed_reviews']).head()
# Out:
#                                 preprocessed_reviews
# 0                                  아 더빙 진짜 짜증나네요 목소리
# 1                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                  너무재밓었다그래서보는것을추천한다
# 3                          교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...

# %%
whole_data.reviews = docs_tr

# %%
whole_data.head()
# Out:
#                                              reviews  sentiment
# 0                                  아 더빙 진짜 짜증나네요 목소리          0
# 1                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나          1
# 2                                  너무재밓었다그래서보는것을추천한다          0
# 3                          교도소 이야기구먼 솔직히 재미는 없다평점 조정          0
# 4  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...          1

# %% [markdown]
# ## 5. 토큰화 전처리

# %% [markdown]
# ### - 5.1 토큰화

# %% [markdown]
# #### - Hannanum: 한나눔. KAIST Semantic Web Research Center 개발.
# #### http://semanticweb.kaist.ac.kr/hannanum/
# #### - Kkma: 꼬꼬마. 서울대학교 IDS(Intelligent Data Systems) 연구실 개발.
# #### http://kkma.snu.ac.kr/
# #### - Komoran: 코모란. Shineware에서 개발.
# #### https://github.com/shin285/KOMORAN
# #### - Mecab: 메카브. 일본어용 형태소 분석기를 한국어를 사용할 수 있도록 수정.
# #### https://bitbucket.org/eunjeon/mecab-ko
# #### - Open Korean Text: 오픈 소스 한국어 분석기. 과거 트위터 형태소 분석기.
# #### https://github.com/open-korean-text/open-korean-text

# %%
# hannanum = Hannanum()
# kkma = Kkma()
# komoran = Komoran()

# nouns: 명사 추출
# morphs: 형태소 추출
# pos: 품사 부착

hannanum = Hannanum()
docs_tr = [hannanum.morphs(review) for review in whole_data.reviews.values.tolist()]

# %%
# 토큰화 결과
whole_data.reviews = docs_tr

# %%
whole_data.head()
# Out:
#                                              reviews  sentiment
# 0                        [아, 더빙, 진짜, 짜증나, 네, 요, 목소리]          0
# 1           [흠포스터보, 이, 고, 초딩영화줄오버연기조차, 가볍, 지, 않, 구나]          1
# 2                                [너무재밓었다그래서보는것을추천한다]          0
# 3                 [교도소, 이야기구먼, 솔직히, 재미, 는, 없다평점, 조정]          0
# 4  [사이몬페그, 의, 익살, 스런, 연기, 가, 돋보이, 었던, 영화스파이더맨, 에서...          1

# %% [markdown]
# ## 6. 토큰화 데이터 탐색

# %% [markdown]
# ### - 6.1 전체 문서에 대한 토큰 생성

# %%
tokens = [tok for sublist in docs_tr for tok in sublist]

# %%
tokens
# Out:
# ['아',
#  '더빙',
#  '진짜',
#  '짜증나',
#  '네',
#  '요',
#  '목소리',
#  '흠포스터보',
#  '이',
#  '고',
#  '초딩영화줄오버연기조차',
#  '가볍',
#  '지',
#  '않',
#  '구나',
#  '너무재밓었다그래서보는것을추천한다',
#  '교도소',
#  '이야기구먼',
#  '솔직히',
#  '재미',
#  '는',
#  '없다평점',
#  '조정',
#  '사이몬페그',
#  '의',
#  '익살',
#  '스런',
#  '연기',
#  '가',
#  '돋보이',
#  '었던',
#  '영화스파이더맨',
#  '에서',
#  '늙',
#  '어',
#  '보이',
#  '기',
#  '만',
#  '하',
#  '었던',
#  '커스틴',
#  '던스트',
#  '가',
#  '너무나',
#  '도',
#  '이쁘',
#  '어',
#  '보이',
#  '었다',
#  '막',
#  '걸음마',
#  '떼',
#  'ㄴ',
#  '3세',
#  '부터',
#  '초등학교',
#  '1학년생',
#  '이',
#  'ㄴ',
#  '8살용영홬ㅋㅋ별반개',
#  '도',
#  '아까움',
#  '원작',
#  '의',
#  '긴장감',
#  '을',
#  '제대로',
#  '살',
#  '려',
#  '내',
#  '지',
#  '못하',
#  '었다',
#  '별',
#  '반개',
#  '도',
#  '아깝',
#  '다',
#  '욕나온다',
#  '이응경',
#  '길용우',
#  '연기생활이몇년인지정말',
#  '발로해',
#  '도',
#  '그것보단',
#  '낫겟다',
#  '납치감금만반복반복이드라마',
#  '는',
#  '가족도',
#  '없',
#  '다',
#  '연기못하는사람만모엿',
#  '네',
#  '액션',
#  '이',
#  '없',
#  '는데',
#  '도',
#  '재미',
#  '있',
#  '는',
#  '몇안되',
#  '는',
#  '영화',
#  '왜케',
#  '평점',
#  '이',
#  '낮',
#  '은',
#  '것',
#  '이',
#  'ㄴ데',
#  '꽤',
#  '보',
#  'ㄹ',
#  '만',
#  '하',
#  'ㄴ데',
#  '헐리우드식',
#  '화',
#  '이',
#  '리어',
#  '하',
#  'ㅁ',
#  '에만',
#  '너무',
#  '길들이',
#  '어',
#  '지',
#  '어',
#  '있',
#  '나',
#  '걍인피니트가짱이다진짜짱',
#  '이',
#  '다',
#  '보',
#  'ㄹ',
#  '때',
#  '마다',
#  '눈물나',
#  '아',
#  '죽겠다90년대',
#  '의',
#  '향수자극허진호',
#  '는',
#  '감성절제멜로',
#  '의',
#  '달인',
#  '이',
#  '다',
#  '울',
#  '면서',
#  '손들',
#  '고',
#  '횡단보도',
#  '건너',
#  'ㄹ',
#  '때',
#  '뛰치',
#  '어',
#  '나',
#  '아',
#  '오',
#  'ㄹ',
#  '뻔',
#  '이범수',
#  '연기',
#  '드럽게못해',
#  '담백',
#  '하고',
#  '깔끔',
#  '하',
#  '어서',
#  '좋',
#  '다',
#  '신문기사',
#  '로만',
#  '보다',
#  '보',
#  '면',
#  '자꾸',
#  '잊',
#  '어',
#  '버리',
#  'ㄴ다',
#  '그들',
#  '도',
#  '사람',
#  '이',
#  '었다는',
#  '것',
#  '을',
#  '취향',
#  '은',
#  '존중한다',
#  '이',
#  '지만',
#  '진짜',
#  '내생',
#  '에',
#  '극장',
#  '에서',
#  '보',
#  'ㄴ',
#  '영화중',
#  '가장',
#  '노잼',
#  '노감동',
#  '이',
#  'ㅁ',
#  '스토리',
#  '도',
#  '어거지',
#  '이',
#  '고',
#  '감동',
#  '도',
#  '어거지',
#  'ㄱ냥',
#  '매번',
#  '긴장',
#  '되',
#  '고',
#  '재밋음ㅠㅠ',
#  '참',
#  '사람들',
#  '웃기',
#  'ㄴ게',
#  '바스코',
#  '가',
#  '이',
#  '이',
#  '기',
#  '이',
#  '면',
#  '락스코라',
#  '이',
#  '고',
#  '까고바비',
#  '가',
#  '이',
#  '이',
#  '기',
#  '이',
#  '면',
#  '아이돌',
#  '이',
#  '라',
#  '고',
#  '깐다그냥',
#  '까',
#  '고',
#  '싶',
#  '어서',
#  '안달난것처럼',
#  '보',
#  '이',
#  'ㄴ다',
#  '굿바',
#  '이',
#  '레닌',
#  '표절',
#  '이',
#  'ㄴ',
#  '것',
#  '은',
#  '이해',
#  '하',
#  'ㄴ데',
#  '왜',
#  '뒤',
#  '로',
#  '가',
#  'ㄹ수록',
#  '재미',
#  '없',
#  '어',
#  '지',
#  '냐',
#  '이',
#  '이',
#  '건',
#  '정말',
#  '깨알',
#  '캐스팅',
#  '과',
#  '질퍽하지않',
#  '은',
#  '산뜻',
#  '하',
#  'ㄴ',
#  '내용구성',
#  '이',
#  '잘',
#  '버무러진',
#  '깨알일드',
#  '약탈자',
#  '를',
#  '위하',
#  'ㄴ',
#  '변명',
#  '이',
#  '이',
#  '라',
#  '저놈들',
#  '은',
#  '착한놈들',
#  '절대',
#  '아닌걸요',
#  '나름',
#  '심오한',
#  '뜻',
#  '도',
#  '있',
#  '는',
#  '듯',
#  '그냥',
#  '학생',
#  '이',
#  '선생',
#  '과',
#  '놀',
#  '아',
#  '나',
#  '는',
#  '영화',
#  '는',
#  '절대',
#  '아니',
#  'ㅁ',
#  '보',
#  '면서',
#  '웃',
#  '지',
#  '않',
#  '는',
#  '거',
#  '은',
#  '불가능',
#  '하',
#  '다',
#  '재미',
#  '없',
#  '다',
#  '지루',
#  '하고',
#  '같',
#  '은',
#  '음식',
#  '영화',
#  '이',
#  'ㄴ데',
#  '도',
#  '바베트',
#  '의',
#  '만찬',
#  '하고',
#  '널',
#  'ㅁ',
#  '차이남바베트',
#  '의',
#  '만찬',
#  '은',
#  '이야기',
#  '도',
#  '있',
#  '고',
#  '음식',
#  '보는재미',
#  '도',
#  '있',
#  '는데',
#  '이',
#  '이',
#  '건',
#  '볼게없다',
#  '음식',
#  '도',
#  '별로',
#  '안나오',
#  '이',
#  '고',
#  '핀란드',
#  '풍경',
#  '이',
#  '라',
#  '도',
#  '구경할랫는데',
#  '그것',
#  '도',
#  '별로',
#  '안나옴',
#  'ㅡㅡ',
#  '절대',
#  '평범',
#  '하',
#  'ㄴ',
#  '영화',
#  '가',
#  '아니',
#  'ㄴ',
#  '수작이라는걸',
#  '말씀드',
#  '이',
#  '리ㅂ니다',
#  '주제',
#  '는',
#  '좋',
#  '은',
#  '데',
#  '중반',
#  '부터',
#  '지루',
#  '하',
#  '다',
#  '다',
#  '짤랐을꺼야',
#  '그래서',
#  '납득',
#  '하',
#  'ㄹ',
#  '수',
#  '없었던거',
#  '야',
#  '그럴꺼',
#  '야',
#  '꼭',
#  '그랬던걸꺼',
#  '야',
#  'kl2g',
#  '고추',
#  '를',
#  '털',
#  '어',
#  '버리',
#  '어야',
#  '하',
#  'ㄹ텐데',
#  '카밀라벨',
#  '발연기',
#  '재밋는뎅',
#  '센스',
#  '있',
#  '는',
#  '연출력탁월',
#  '하',
#  'ㄴ',
#  '캐스팅90년대',
#  '의',
#  '향수',
#  '그래서',
#  '9점',
#  '엄포스',
#  '의',
#  '위력',
#  '을',
#  '다시',
#  '한번',
#  '깨닫',
#  '게',
#  '하',
#  '어',
#  '주',
#  'ㄴ',
#  '적남',
#  '꽃검사님',
#  '도',
#  '연기',
#  '정말',
#  '좋',
#  '아아',
#  '요',
#  '완전',
#  '명품드라마',
#  '졸쓰레',
#  '이',
#  '기',
#  '진부하고말도안됌ㅋㅋ',
#  '아시간아까워',
#  '재밌는데',
#  '별점',
#  '이',
#  '왜이리',
#  '낮은',
#  '고',
#  '1',
#  '라도',
#  '기대',
#  '어',
#  '하',
#  '었던',
#  '나',
#  '가',
#  '죄인',
#  '이',
#  'ㅂ니다',
#  '죄인',
#  '이',
#  'ㅂ니다',
#  '아직',
#  '도',
#  '이',
#  '드라마',
#  '는',
#  '내인생',
#  '의',
#  '최고',
#  '패션',
#  '에',
#  '대하',
#  'ㄴ',
#  '열정',
#  '안',
#  '나',
#  '윈투',
#  '이',
#  '어',
#  '키',
#  '이',
#  '라',
#  '나이틀리',
#  '가',
#  '연기',
#  '하',
#  '고자',
#  '했던건',
#  '대체',
#  '정신장애',
#  '이',
#  'ㄹ까',
#  '틱장애',
#  '이',
#  'ㄹ까',
#  '허허원작',
#  '가',
#  '정신나',
#  '아',
#  '가',
#  'ㄴ',
#  '유령',
#  '이',
#  '라',
#  '재미있',
#  '겠네요',
#  '포스터',
#  '는',
#  '있',
#  '어',
#  '보이',
#  'ㄴ데',
#  '관객',
#  '은',
#  '114명',
#  '이',
#  '네',
#  '이',
#  '영화',
#  '가',
#  '왜',
#  '이렇',
#  '게',
#  '저평가',
#  '받',
#  '는지',
#  '모르',
#  '겠다',
#  '단순',
#  '하',
#  '면서',
#  '은은',
#  '하',
#  'ㄴ',
#  '매력',
#  '의',
#  '영화',
#  '다',
#  '알바생인',
#  '가',
#  '내용',
#  '도',
#  '없',
#  '고',
#  '무서운거',
#  '도',
#  '없',
#  '고',
#  '웃긴거',
#  '도',
#  '하',
#  '어',
#  '나',
#  '아',
#  '없',
#  '음',
#  '완전',
#  '별싱거운',
#  '영황ㅇ냉시간',
#  '널',
#  'ㅁ',
#  '아깝',
#  '음',
#  '완전',
#  '낚',
#  '이',
#  'ㅁ',
#  '오',
#  '게',
#  '두',
#  '어라',
#  '서리한',
#  '이',
#  '굶주리',
#  '었다',
#  '정말',
#  '말',
#  'ㅁ',
#  '에',
#  '들',
#  '어',
#  '요',
#  '그래서',
#  '또',
#  '보',
#  '고',
#  '싶',
#  '은',
#  '데',
#  '또',
#  '보',
#  '는',
#  '방법',
#  '이',
#  '없',
#  '네',
#  'ㅜㅡ',
#  '윤제문이라',
#  '는',
#  '멋지',
#  'ㄴ',
#  '배우',
#  '를',
#  '발견',
#  '하',
#  '게',
#  '되',
#  '었어',
#  '요',
#  '소소한',
#  '일탈',
#  '이',
#  '잔잔한',
#  '미소',
#  '를',
#  '머금',
#  '게',
#  '하',
#  'ㅂ니다',
#  '음악',
#  '은',
#  '조금',
#  '아쉽네요ㅠㅠ',
#  '8점',
#  '주',
#  '고',
#  '싶',
#  '은',
#  '데',
#  '평점',
#  '오',
#  'ㄹ',
#  '리',
#  '이',
#  '고',
#  '싶',
#  '어',
#  '10점',
#  '줄',
#  '게',
#  '요',
#  '평점에속지마시길시간낭비',
#  '돈낭비임',
#  '리얼리티',
#  '가',
#  '뛰어나긴',
#  '하',
#  'ㄴ데',
#  '크',
#  'ㄴ',
#  '공감',
#  '은',
#  '안간다',
#  '이민기캐릭터',
#  '는',
#  '정신의학상',
#  '분노조절장애',
#  '초',
#  '이',
#  '기',
#  '증상일거',
#  '이',
#  '다',
#  '툭하면',
#  '사람패',
#  '이',
#  '고',
#  '욕',
#  '하고',
#  '물건',
#  '파손',
#  '하고',
#  '조금',
#  '오바',
#  '이',
#  '었음',
#  '극',
#  '초반',
#  '엔',
#  '신선',
#  '하',
#  '었는데',
#  '가',
#  '면',
#  '가',
#  'ㄹ수록',
#  '이민기',
#  '정신상태',
#  '공감불가',
#  '마이너스',
#  '는',
#  '왜없냐',
#  'ㅋ',
#  '뮤비',
#  '보',
#  '고',
#  '영화수준',
#  '딱',
#  '알',
#  'ㄹ',
#  '만',
#  '하',
#  '더군',
#  'ㅉㅉ',
#  '북한',
#  '에서',
#  '이런거',
#  '만들',
#  '라',
#  '고',
#  '돌',
#  'ㄴ',
#  '대주',
#  '이',
#  '던',
#  '나',
#  'ㄴ',
#  '우리영화',
#  '를',
#  '사랑',
#  '하',
#  'ㅂ니다',
#  '데너리스',
#  '타르',
#  '가르엔나',
#  '도',
#  '용의주인',
#  '이',
#  '되',
#  '고',
#  '싶다누이랑근친상간',
#  '이나',
#  '하',
#  '고',
#  '다닐지라도소설',
#  '속',
#  '에선',
#  '제일',
#  '멋지',
#  'ㄴ',
#  '놈',
#  '이',
#  '자이메',
#  '라니스터였는데드라마속에선드래곤용',
#  '이',
#  '제일',
#  '멋지네웃음감독님',
#  '토르2',
#  '다크',
#  '월드',
#  '는',
#  '말',
#  '아',
#  '잡수셨을지라도기본',
#  '선방',
#  '은',
#  '하',
#  '었음',
#  '영화',
#  '가',
#  '사람',
#  '의',
#  '영혼',
#  '을',
#  '어루만지',
#  '어',
#  '주',
#  'ㄹ',
#  '수',
#  '도',
#  '있',
#  '군',
#  '요',
#  '거칠',
#  'ㄴ',
#  '세상사',
#  '를',
#  '잠시',
#  '잊',
#  '고',
#  '동화',
#  '같',
#  '은',
#  '영화',
#  '에',
#  '행복',
#  '하',
#  '었네요',
#  '야',
#  '세르게',
#  '이',
#  '작은고추',
#  '의',
#  '매운맛',
#  '을',
#  '보이',
#  '어',
#  '주',
#  '마',
#  '포퐁저그',
#  '콩진호',
#  '가',
#  '갈',
#  'ㄴ다',
#  '이렇',
#  '게',
#  '가슴시',
#  '이',
#  '리게',
#  '보',
#  'ㄴ',
#  '드라마',
#  '가',
#  '또',
#  '있',
#  '을까',
#  '감동',
#  '그',
#  '자체',
#  '난또',
#  '저',
#  '꼬마애',
#  '가',
#  '무슨',
#  '원한',
#  '이',
#  '깊',
#  '길래',
#  '하',
#  '었더니',
#  'OO',
#  '그냥',
#  '혼자',
#  '나',
#  '아',
#  '대',
#  '어다',
#  'OO',
#  '걸',
#  '어쩌',
#  '라고',
#  '재미있',
#  '어요',
#  '전',
#  '좋',
#  '아요',
#  '최고',
#  '너무',
#  '충격적이엇다',
#  '기분',
#  '을',
#  '완전히',
#  '푹',
#  '꺼지',
#  '게',
#  '하',
#  '는',
#  '느끼',
#  'ㅁ',
#  '활력',
#  '이',
#  '라',
#  '고는',
#  '하',
#  '어',
#  '나',
#  '아',
#  '없',
#  '는',
#  '너무나',
#  '도',
#  '무거운지독하',
#  '이',
#  '고',
#  '차갑',
#  '고',
#  '무자비',
#  '하',
#  '어다',
#  '그저',
#  '일본인들',
#  '의',
#  '상상력',
#  '은',
#  '정말',
#  '대단한거',
#  '같',
#  '다는',
#  '생각',
#  '이',
#  '들',
#  'ㄴ다',
#  '심심한영화',
#  '백봉기',
#  '언제나오',
#  '이',
#  '나요',
#  '보는내내',
#  '그대로',
#  '들어맞',
#  '는',
#  '예측',
#  '카리스마',
#  '없',
#  '는',
#  '악역',
#  '불알',
#  '이',
#  '나오',
#  '아',
#  '당황아무튼',
#  '영화',
#  '가',
#  '중간',
#  '에',
#  '끝나',
#  '는',
#  '느낌',
#  '평범',
#  '하',
#  'ㅁ',
#  '속',
#  '에',
#  '녹',
#  '아',
#  '든',
#  '평범',
#  '하',
#  'ㄴ',
#  '일상',
#  '조금',
#  '밋밋하',
#  'ㄴ게',
#  '흠',
#  '보',
#  '던',
#  '것',
#  '이',
#  '라',
#  '계속보',
#  '이',
#  '고',
#  '있',
#  '는데',
#  '전개도',
#  '느리',
#  '고',
#  '주인공',
#  '이',
#  'ㄴ',
#  '은희',
#  '는',
#  '한두컷',
#  '나',
#  '아',
#  '오',
#  '면서',
#  '소극적인모습',
#  '에',
#  '짜증',
#  '이',
#  'ㅜㅜ',
#  ...]

# %% [markdown]
# ### - 6.2 nltk 객체 생성

# %%
text = nltk.Text(tokens)

# %% [markdown]
# ### - 6.3 중복을 제외한 토큰의 수

# %%
print(len(set(text.tokens)))
# Out:
# 28713

# %% [markdown]
# ### - 6.4 전체 문서에서 가장 많이 나온 토큰 10개 확인

# %%
print(text.vocab().most_common(10))
# Out:
# [('이', 12456), ('하', 5468), ('는', 4611), ('ㄴ', 4359), ('고', 3557), ('영화', 3261), ('가', 3182), ('어', 3047), ('의', 2978), ('보', 2950)]

# %% [markdown]
# ## 7. Term-Document Matrix

# %%
vectorizer = CountVectorizer()
vectorizer
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %% [markdown]
# ### - 7.1 train / test 데이터 나누기

# %%
train_docs = whole_data.reviews.values.tolist()[:len(train_data)]
test_docs= whole_data.reviews.values.tolist()[-len(test_data):]
train_docs
# Out:
# [['아', '더빙', '진짜', '짜증나', '네', '요', '목소리'],
#  ['흠포스터보', '이', '고', '초딩영화줄오버연기조차', '가볍', '지', '않', '구나'],
#  ['너무재밓었다그래서보는것을추천한다'],
#  ['교도소', '이야기구먼', '솔직히', '재미', '는', '없다평점', '조정'],
#  ['사이몬페그',
#   '의',
#   '익살',
#   '스런',
#   '연기',
#   '가',
#   '돋보이',
#   '었던',
#   '영화스파이더맨',
#   '에서',
#   '늙',
#   '어',
#   '보이',
#   '기',
#   '만',
#   '하',
#   '었던',
#   '커스틴',
#   '던스트',
#   '가',
#   '너무나',
#   '도',
#   '이쁘',
#   '어',
#   '보이',
#   '었다'],
#  ['막',
#   '걸음마',
#   '떼',
#   'ㄴ',
#   '3세',
#   '부터',
#   '초등학교',
#   '1학년생',
#   '이',
#   'ㄴ',
#   '8살용영홬ㅋㅋ별반개',
#   '도',
#   '아까움'],
#  ['원작', '의', '긴장감', '을', '제대로', '살', '려', '내', '지', '못하', '었다'],
#  ['별',
#   '반개',
#   '도',
#   '아깝',
#   '다',
#   '욕나온다',
#   '이응경',
#   '길용우',
#   '연기생활이몇년인지정말',
#   '발로해',
#   '도',
#   '그것보단',
#   '낫겟다',
#   '납치감금만반복반복이드라마',
#   '는',
#   '가족도',
#   '없',
#   '다',
#   '연기못하는사람만모엿',
#   '네'],
#  ['액션', '이', '없', '는데', '도', '재미', '있', '는', '몇안되', '는', '영화'],
#  ['왜케',
#   '평점',
#   '이',
#   '낮',
#   '은',
#   '것',
#   '이',
#   'ㄴ데',
#   '꽤',
#   '보',
#   'ㄹ',
#   '만',
#   '하',
#   'ㄴ데',
#   '헐리우드식',
#   '화',
#   '이',
#   '리어',
#   '하',
#   'ㅁ',
#   '에만',
#   '너무',
#   '길들이',
#   '어',
#   '지',
#   '어',
#   '있',
#   '나'],
#  ['걍인피니트가짱이다진짜짱', '이', '다'],
#  ['보',
#   'ㄹ',
#   '때',
#   '마다',
#   '눈물나',
#   '아',
#   '죽겠다90년대',
#   '의',
#   '향수자극허진호',
#   '는',
#   '감성절제멜로',
#   '의',
#   '달인',
#   '이',
#   '다'],
#  ['울',
#   '면서',
#   '손들',
#   '고',
#   '횡단보도',
#   '건너',
#   'ㄹ',
#   '때',
#   '뛰치',
#   '어',
#   '나',
#   '아',
#   '오',
#   'ㄹ',
#   '뻔',
#   '이범수',
#   '연기',
#   '드럽게못해'],
#  ['담백',
#   '하고',
#   '깔끔',
#   '하',
#   '어서',
#   '좋',
#   '다',
#   '신문기사',
#   '로만',
#   '보다',
#   '보',
#   '면',
#   '자꾸',
#   '잊',
#   '어',
#   '버리',
#   'ㄴ다',
#   '그들',
#   '도',
#   '사람',
#   '이',
#   '었다는',
#   '것',
#   '을'],
#  ['취향',
#   '은',
#   '존중한다',
#   '이',
#   '지만',
#   '진짜',
#   '내생',
#   '에',
#   '극장',
#   '에서',
#   '보',
#   'ㄴ',
#   '영화중',
#   '가장',
#   '노잼',
#   '노감동',
#   '이',
#   'ㅁ',
#   '스토리',
#   '도',
#   '어거지',
#   '이',
#   '고',
#   '감동',
#   '도',
#   '어거지'],
#  ['ㄱ냥', '매번', '긴장', '되', '고', '재밋음ㅠㅠ'],
#  ['참',
#   '사람들',
#   '웃기',
#   'ㄴ게',
#   '바스코',
#   '가',
#   '이',
#   '이',
#   '기',
#   '이',
#   '면',
#   '락스코라',
#   '이',
#   '고',
#   '까고바비',
#   '가',
#   '이',
#   '이',
#   '기',
#   '이',
#   '면',
#   '아이돌',
#   '이',
#   '라',
#   '고',
#   '깐다그냥',
#   '까',
#   '고',
#   '싶',
#   '어서',
#   '안달난것처럼',
#   '보',
#   '이',
#   'ㄴ다'],
#  ['굿바',
#   '이',
#   '레닌',
#   '표절',
#   '이',
#   'ㄴ',
#   '것',
#   '은',
#   '이해',
#   '하',
#   'ㄴ데',
#   '왜',
#   '뒤',
#   '로',
#   '가',
#   'ㄹ수록',
#   '재미',
#   '없',
#   '어',
#   '지',
#   '냐'],
#  ['이',
#   '이',
#   '건',
#   '정말',
#   '깨알',
#   '캐스팅',
#   '과',
#   '질퍽하지않',
#   '은',
#   '산뜻',
#   '하',
#   'ㄴ',
#   '내용구성',
#   '이',
#   '잘',
#   '버무러진',
#   '깨알일드'],
#  ['약탈자',
#   '를',
#   '위하',
#   'ㄴ',
#   '변명',
#   '이',
#   '이',
#   '라',
#   '저놈들',
#   '은',
#   '착한놈들',
#   '절대',
#   '아닌걸요'],
#  ['나름',
#   '심오한',
#   '뜻',
#   '도',
#   '있',
#   '는',
#   '듯',
#   '그냥',
#   '학생',
#   '이',
#   '선생',
#   '과',
#   '놀',
#   '아',
#   '나',
#   '는',
#   '영화',
#   '는',
#   '절대',
#   '아니',
#   'ㅁ'],
#  ['보', '면서', '웃', '지', '않', '는', '거', '은', '불가능', '하', '다'],
#  ['재미',
#   '없',
#   '다',
#   '지루',
#   '하고',
#   '같',
#   '은',
#   '음식',
#   '영화',
#   '이',
#   'ㄴ데',
#   '도',
#   '바베트',
#   '의',
#   '만찬',
#   '하고',
#   '널',
#   'ㅁ',
#   '차이남바베트',
#   '의',
#   '만찬',
#   '은',
#   '이야기',
#   '도',
#   '있',
#   '고',
#   '음식',
#   '보는재미',
#   '도',
#   '있',
#   '는데',
#   '이',
#   '이',
#   '건',
#   '볼게없다',
#   '음식',
#   '도',
#   '별로',
#   '안나오',
#   '이',
#   '고',
#   '핀란드',
#   '풍경',
#   '이',
#   '라',
#   '도',
#   '구경할랫는데',
#   '그것',
#   '도',
#   '별로',
#   '안나옴',
#   'ㅡㅡ'],
#  ['절대', '평범', '하', 'ㄴ', '영화', '가', '아니', 'ㄴ', '수작이라는걸', '말씀드', '이', '리ㅂ니다'],
#  ['주제', '는', '좋', '은', '데', '중반', '부터', '지루', '하', '다'],
#  ['다',
#   '짤랐을꺼야',
#   '그래서',
#   '납득',
#   '하',
#   'ㄹ',
#   '수',
#   '없었던거',
#   '야',
#   '그럴꺼',
#   '야',
#   '꼭',
#   '그랬던걸꺼',
#   '야'],
#  ['kl2g', '고추', '를', '털', '어', '버리', '어야', '하', 'ㄹ텐데'],
#  ['카밀라벨', '발연기'],
#  ['재밋는뎅'],
#  ['센스', '있', '는', '연출력탁월', '하', 'ㄴ', '캐스팅90년대', '의', '향수', '그래서', '9점'],
#  ['엄포스',
#   '의',
#   '위력',
#   '을',
#   '다시',
#   '한번',
#   '깨닫',
#   '게',
#   '하',
#   '어',
#   '주',
#   'ㄴ',
#   '적남',
#   '꽃검사님',
#   '도',
#   '연기',
#   '정말',
#   '좋',
#   '아아',
#   '요',
#   '완전',
#   '명품드라마'],
#  ['졸쓰레', '이', '기', '진부하고말도안됌ㅋㅋ', '아시간아까워'],
#  ['재밌는데', '별점', '이', '왜이리', '낮은', '고'],
#  ['1',
#   '라도',
#   '기대',
#   '어',
#   '하',
#   '었던',
#   '나',
#   '가',
#   '죄인',
#   '이',
#   'ㅂ니다',
#   '죄인',
#   '이',
#   'ㅂ니다'],
#  ['아직', '도', '이', '드라마', '는', '내인생', '의', '최고'],
#  ['패션', '에', '대하', 'ㄴ', '열정', '안', '나', '윈투', '이', '어'],
#  ['키',
#   '이',
#   '라',
#   '나이틀리',
#   '가',
#   '연기',
#   '하',
#   '고자',
#   '했던건',
#   '대체',
#   '정신장애',
#   '이',
#   'ㄹ까',
#   '틱장애',
#   '이',
#   'ㄹ까'],
#  ['허허원작', '가', '정신나', '아', '가', 'ㄴ', '유령', '이', '라', '재미있', '겠네요'],
#  ['포스터', '는', '있', '어', '보이', 'ㄴ데', '관객', '은', '114명', '이', '네'],
#  ['이', '영화', '가', '왜', '이렇', '게', '저평가', '받', '는지', '모르', '겠다'],
#  ['단순', '하', '면서', '은은', '하', 'ㄴ', '매력', '의', '영화'],
#  ['다',
#   '알바생인',
#   '가',
#   '내용',
#   '도',
#   '없',
#   '고',
#   '무서운거',
#   '도',
#   '없',
#   '고',
#   '웃긴거',
#   '도',
#   '하',
#   '어',
#   '나',
#   '아',
#   '없',
#   '음',
#   '완전',
#   '별싱거운',
#   '영황ㅇ냉시간',
#   '널',
#   'ㅁ',
#   '아깝',
#   '음',
#   '완전',
#   '낚',
#   '이',
#   'ㅁ'],
#  ['오', '게', '두', '어라', '서리한', '이', '굶주리', '었다'],
#  ['정말',
#   '말',
#   'ㅁ',
#   '에',
#   '들',
#   '어',
#   '요',
#   '그래서',
#   '또',
#   '보',
#   '고',
#   '싶',
#   '은',
#   '데',
#   '또',
#   '보',
#   '는',
#   '방법',
#   '이',
#   '없',
#   '네',
#   'ㅜㅡ'],
#  ['윤제문이라',
#   '는',
#   '멋지',
#   'ㄴ',
#   '배우',
#   '를',
#   '발견',
#   '하',
#   '게',
#   '되',
#   '었어',
#   '요',
#   '소소한',
#   '일탈',
#   '이',
#   '잔잔한',
#   '미소',
#   '를',
#   '머금',
#   '게',
#   '하',
#   'ㅂ니다',
#   '음악',
#   '은',
#   '조금',
#   '아쉽네요ㅠㅠ',
#   '8점',
#   '주',
#   '고',
#   '싶',
#   '은',
#   '데',
#   '평점',
#   '오',
#   'ㄹ',
#   '리',
#   '이',
#   '고',
#   '싶',
#   '어',
#   '10점',
#   '줄',
#   '게',
#   '요'],
#  ['평점에속지마시길시간낭비', '돈낭비임'],
#  ['리얼리티',
#   '가',
#   '뛰어나긴',
#   '하',
#   'ㄴ데',
#   '크',
#   'ㄴ',
#   '공감',
#   '은',
#   '안간다',
#   '이민기캐릭터',
#   '는',
#   '정신의학상',
#   '분노조절장애',
#   '초',
#   '이',
#   '기',
#   '증상일거',
#   '이',
#   '다',
#   '툭하면',
#   '사람패',
#   '이',
#   '고',
#   '욕',
#   '하고',
#   '물건',
#   '파손',
#   '하고',
#   '조금',
#   '오바',
#   '이',
#   '었음',
#   '극',
#   '초반',
#   '엔',
#   '신선',
#   '하',
#   '었는데',
#   '가',
#   '면',
#   '가',
#   'ㄹ수록',
#   '이민기',
#   '정신상태',
#   '공감불가'],
#  ['마이너스',
#   '는',
#   '왜없냐',
#   'ㅋ',
#   '뮤비',
#   '보',
#   '고',
#   '영화수준',
#   '딱',
#   '알',
#   'ㄹ',
#   '만',
#   '하',
#   '더군',
#   'ㅉㅉ',
#   '북한',
#   '에서',
#   '이런거',
#   '만들',
#   '라',
#   '고',
#   '돌',
#   'ㄴ',
#   '대주',
#   '이',
#   '던'],
#  ['나', 'ㄴ', '우리영화', '를', '사랑', '하', 'ㅂ니다'],
#  ['데너리스',
#   '타르',
#   '가르엔나',
#   '도',
#   '용의주인',
#   '이',
#   '되',
#   '고',
#   '싶다누이랑근친상간',
#   '이나',
#   '하',
#   '고',
#   '다닐지라도소설',
#   '속',
#   '에선',
#   '제일',
#   '멋지',
#   'ㄴ',
#   '놈',
#   '이',
#   '자이메',
#   '라니스터였는데드라마속에선드래곤용',
#   '이',
#   '제일',
#   '멋지네웃음감독님',
#   '토르2',
#   '다크',
#   '월드',
#   '는',
#   '말',
#   '아',
#   '잡수셨을지라도기본',
#   '선방',
#   '은',
#   '하',
#   '었음'],
#  ['영화',
#   '가',
#   '사람',
#   '의',
#   '영혼',
#   '을',
#   '어루만지',
#   '어',
#   '주',
#   'ㄹ',
#   '수',
#   '도',
#   '있',
#   '군',
#   '요',
#   '거칠',
#   'ㄴ',
#   '세상사',
#   '를',
#   '잠시',
#   '잊',
#   '고',
#   '동화',
#   '같',
#   '은',
#   '영화',
#   '에',
#   '행복',
#   '하',
#   '었네요'],
#  ['야',
#   '세르게',
#   '이',
#   '작은고추',
#   '의',
#   '매운맛',
#   '을',
#   '보이',
#   '어',
#   '주',
#   '마',
#   '포퐁저그',
#   '콩진호',
#   '가',
#   '갈',
#   'ㄴ다'],
#  ['이렇',
#   '게',
#   '가슴시',
#   '이',
#   '리게',
#   '보',
#   'ㄴ',
#   '드라마',
#   '가',
#   '또',
#   '있',
#   '을까',
#   '감동',
#   '그',
#   '자체'],
#  ['난또',
#   '저',
#   '꼬마애',
#   '가',
#   '무슨',
#   '원한',
#   '이',
#   '깊',
#   '길래',
#   '하',
#   '었더니',
#   'OO',
#   '그냥',
#   '혼자',
#   '나',
#   '아',
#   '대',
#   '어다',
#   'OO',
#   '걸',
#   '어쩌',
#   '라고'],
#  ['재미있', '어요'],
#  ['전', '좋', '아요'],
#  ['최고'],
#  ['너무',
#   '충격적이엇다',
#   '기분',
#   '을',
#   '완전히',
#   '푹',
#   '꺼지',
#   '게',
#   '하',
#   '는',
#   '느끼',
#   'ㅁ',
#   '활력',
#   '이',
#   '라',
#   '고는',
#   '하',
#   '어',
#   '나',
#   '아',
#   '없',
#   '는',
#   '너무나',
#   '도',
#   '무거운지독하',
#   '이',
#   '고',
#   '차갑',
#   '고',
#   '무자비',
#   '하',
#   '어다',
#   '그저',
#   '일본인들',
#   '의',
#   '상상력',
#   '은',
#   '정말',
#   '대단한거',
#   '같',
#   '다는',
#   '생각',
#   '이',
#   '들',
#   'ㄴ다'],
#  ['심심한영화'],
#  ['백봉기', '언제나오', '이', '나요'],
#  ['보는내내', '그대로', '들어맞', '는', '예측', '카리스마', '없', '는', '악역'],
#  ['불알', '이', '나오', '아', '당황아무튼', '영화', '가', '중간', '에', '끝나', '는', '느낌'],
#  ['평범',
#   '하',
#   'ㅁ',
#   '속',
#   '에',
#   '녹',
#   '아',
#   '든',
#   '평범',
#   '하',
#   'ㄴ',
#   '일상',
#   '조금',
#   '밋밋하',
#   'ㄴ게',
#   '흠'],
#  ['보',
#   '던',
#   '것',
#   '이',
#   '라',
#   '계속보',
#   '이',
#   '고',
#   '있',
#   '는데',
#   '전개도',
#   '느리',
#   '고',
#   '주인공',
#   '이',
#   'ㄴ',
#   '은희',
#   '는',
#   '한두컷',
#   '나',
#   '아',
#   '오',
#   '면서',
#   '소극적인모습',
#   '에',
#   '짜증',
#   '이',
#   'ㅜㅜ',
#   '맨날',
#   '언제끝나',
#   '나',
#   '기대만하고있어요',
#   '전개좀',
#   '빨리빨리',
#   'ㅜㅜ'],
#  ['사랑하고싶게하는가슴속온감정을헤집어놓는영화예요정말최', '고'],
#  ['많',
#   '은',
#   '사람',
#   '들',
#   '이',
#   '이',
#   '다큐',
#   '를',
#   '보',
#   '고',
#   '우리나라',
#   '슬프',
#   'ㄴ',
#   '현대사',
#   '의',
#   '한',
#   '단면',
#   '에',
#   '대',
#   '어',
#   '하',
#   '어',
#   '깊이',
#   '생각',
#   '하고',
#   '사죄',
#   '하고',
#   '바로',
#   '잡',
#   '기',
#   '위하',
#   '어',
#   '노력',
#   '하',
#   '었으면',
#   '하',
#   'ㅂ니다',
#   '말',
#   '로만',
#   '듣',
#   '던',
#   '보도연맹',
#   '그',
#   '민간',
#   '이',
#   'ㄴ',
#   '학살',
#   '이',
#   '이정',
#   '도',
#   '일',
#   '줄',
#   '이야',
#   '이',
#   '이',
#   '건',
#   '명백한',
#   '살인',
#   '이',
#   'ㅂ니다',
#   '살인자들',
#   '은',
#   '다',
#   '어디있나요'],
#  ['예전',
#   '작품',
#   '캐릭터',
#   '에피소드',
#   '재탕',
#   '삼탕',
#   '사골우려먹듯',
#   '우리',
#   '이',
#   '고',
#   '내용',
#   '은',
#   '산',
#   '으로',
#   '가',
#   '고',
#   '시청률',
#   '은',
#   '아예안나오',
#   '이',
#   '고',
#   '이제',
#   '70회중반',
#   '이',
#   'ㄴ데',
#   '120부작',
#   '이라이',
#   '니'],
#  ['김남길',
#   '의',
#   '백점',
#   '짜리',
#   '연기력',
#   '과',
#   '초반',
#   '몰입도',
#   '에도',
#   '불구',
#   '하고',
#   '지루',
#   '하고',
#   '손예진',
#   'ㅈㅈ'],
#  ['재밌네',
#   '비슷',
#   '하',
#   'ㄴ',
#   '영화',
#   '를',
#   '안보',
#   '이',
#   '시ㄴ',
#   '불',
#   'ㄴ',
#   '들',
#   '한테는',
#   '재미있',
#   '을',
#   '듯'],
#  ['노래실력으로뽑는',
#   '게',
#   '맞',
#   '냐',
#   '박시환',
#   '이',
#   'mama나가',
#   '이',
#   '면',
#   '진짜',
#   '망신',
#   '이',
#   '다'],
#  ['아', '일본영화', '다이런', '건', '가', '유치', '하', '다'],
#  ['이틀만',
#   '에',
#   '다',
#   '보',
#   '아아',
#   '요',
#   '재밌어요',
#   '근데',
#   '차',
#   '안',
#   '에',
#   '물건',
#   '넣',
#   '어',
#   '조작',
#   '하',
#   '려고',
#   '하',
#   '면',
#   '차',
#   '아',
#   '안',
#   '이',
#   '열리',
#   '어',
#   '있',
#   '다던',
#   '지',
#   '집',
#   '안',
#   '이',
#   '활짝',
#   '열리',
#   '어서',
#   '아무',
#   '나',
#   '들어간다던',
#   '가',
#   '문자',
#   '를',
#   '조작',
#   '하',
#   '려고',
#   '하',
#   '면',
#   '비번',
#   '이',
#   '안',
#   '걸리',
#   '어',
#   '있',
#   '고',
#   'ㅋㅋㅋ',
#   '그러',
#   'ㄴ',
#   '거',
#   '은',
#   '억지',
#   '스럽',
#   '었는데',
#   '그래도',
#   '내용',
#   '자체',
#   '는',
#   '좋',
#   '아아'],
#  ['졸작'],
#  ['재밋네요', '달팽이', '가', '빠르', '아', '더', '재밌었어요'],
#  ['어설프', 'ㄴ', '전개', '어이없', '는', '결말'],
#  ['부패',
#   '하',
#   'ㄴ',
#   '로마노프',
#   '왕조',
#   '를',
#   '기',
#   '리는',
#   '뭣같',
#   '은',
#   '영화',
#   '온몸',
#   '으로',
#   '항거',
#   '하',
#   '었던',
#   '러시아',
#   '민중들',
#   '이',
#   '그저',
#   '폭도',
#   '이',
#   '냐'],
#  ['내용전개', '는', '무난', '하', 'ㄴ', '편이였구', '잘', '보', '아ㅂ니다'],
#  ['매우', '실망'],
#  ['한국영화',
#   '흥행코드',
#   '갈등갈등계에속',
#   '갈등화해감동',
#   '평점',
#   '10점',
#   '남발',
#   '흥행',
#   '뻔하',
#   '지',
#   '뭐'],
#  ['아햏햏', '아햏햏', '아햏햏'],
#  ['뭐냐시작하',
#   '이',
#   '고',
#   '3분',
#   '만에',
#   '나오',
#   '아다',
#   '.',
#   '리플릿',
#   '사',
#   '아',
#   '지',
#   'ㄴ',
#   '보',
#   '며',
#   '불안',
#   '하',
#   '더니',
#   '만'],
#  ['단연', '최고', '이', '라', '고', '하', 'ㄹ', '수', '있', '지'],
#  ['감독',
#   '이',
#   '럼먹고',
#   '영화',
#   '를',
#   '만들었나보다',
#   '관객',
#   '에게',
#   '뭐',
#   '을',
#   '말',
#   '하',
#   '는지',
#   '도',
#   '모르',
#   '겠고',
#   '엉망진창',
#   '개진창',
#   '이',
#   '다'],
#  ['이', '이', '건', '뭐', '이', '냐', '우뢰매', '이', '냐'],
#  ['정말쓰레기영화', '이', 'ㅂ니다'],
#  ['진정', '위대한', '영화', '최고임'],
#  ['별루', '였다'],
#  ['내일', '이', '기대', '되', '는'],
#  ['근데', '조미', '가', '막문위', '좋', '아', '하', 'ㄴ', '것', '이', 'ㄴ가', '요'],
#  ['ㅋㅋㅋ', '진짜', '골깜ㅋㅋ', '눈', '부라리', 'ㄹ', '때', '쓰러짐ㅋㅋ'],
#  ['성룡영화중', '최악', '이', 'ㄴ', '듯', 'ㅋㅋ'],
#  ['골때리넼ㅋㅋㅋ', '걸스데', '이', '이혜리', '잘', '되', '이', '라'],
#  ['서기가이뻐', '서'],
#  ['완전', '재밌어욬ㅋㅋㅋㅋ백인공주귀여움ㅋㅋㅋㅋㅋ', 'ㅋ'],
#  ['인상적', '이', 'ㄴ', '영화', '이', '었다'],
#  ['어내스트', '와', '셀레스틴', '완전', '강추에요', '정말', '재밌습니', '이', '다'],
#  ['재미있는영화', '이', 'ㅂ니다'],
#  ['클라라볼라고화신본거아닌데'],
#  ['진짜', '보', '면서', '너무', '슬프', '었던', '영화', '이', '다'],
#  ['설정',
#   '이',
#   '재밌고',
#   '새롭',
#   '은',
#   '에피소드',
#   '내',
#   '에서',
#   '메이',
#   'ㄴ',
#   '스토리',
#   '도',
#   '차차',
#   '나',
#   '아',
#   '오',
#   '는게',
#   '재밌음'],
#  ['신',
#   '카',
#   '이',
#   '마코토',
#   '의',
#   '작화와미유',
#   '와',
#   '하나카나',
#   '가',
#   '연기',
#   '를',
#   '잘하',
#   '어',
#   '주',
#   '어서',
#   '더대박이',
#   '이',
#   '었다'],
#  ['재미', '없', '음', '진심', '1이훨', '나', '캐스팅두못한듯'],
#  ['잔잔한', '게', '생각', '보다', '보', 'ㄹ', '만', '하', 'ㄴ', '영화인거', '같', '습니다', 'ㅋ'],
#  ['감독님', '들', '고은님', '쓰', '면', '영화안봅니', '이', '다'],
#  ['무섭', '지', '도', '않', '아고', '스토리', '도', 'ㅡㅡ'],
#  ['영화속',
#   '억지',
#   '스럽',
#   '고',
#   '노골적',
#   '이',
#   'ㄴ',
#   '술광고',
#   '를',
#   '좀',
#   '은은',
#   '하고',
#   '센스',
#   '있',
#   '게',
#   '하',
#   '었으면',
#   '어떻',
#   '었을까'],
#  ['킬링타', '이', 'ㅁ'],
#  ['크리스마스하', '이', '면', '떠오르는영화'],
#  ['재미있', '게', '보', '아ㅂ니다', '매력적', '이', 'ㄴ', '행복', '이', '네', '요', 'ㅎㅎㅎ'],
#  ['음악',
#   '에',
#   '완전히',
#   '빠지',
#   '어서',
#   '보',
#   'ㄹ',
#   '수',
#   '있',
#   '었던',
#   '영화',
#   '쪼',
#   'ㅁ',
#   '산만하긴',
#   '하',
#   '던데'],
#  ['태어나',
#   '아',
#   '처음',
#   '으로',
#   '영화',
#   '보다',
#   '중간',
#   '에',
#   '나왔습니다불륜',
#   '이',
#   '로맨스',
#   '이',
#   '냐'],
#  ['왕짜증아주', '전개', '를', '짬뽕', '으로', '믹스했구나음향만', '무섭게하네하', '아'],
#  ['솔직히', '나', 'ㄴ', '별루더', '이', '라', '시간낭비느낌'],
#  ['대박'],
#  ['시청률',
#   '기준',
#   '이',
#   '되',
#   '는',
#   '패널가구들',
#   '머하는거지',
#   '명작드라마',
#   '다',
#   '망치',
#   '이',
#   '네',
#   'ㅡㅡ',
#   '나',
#   '가',
#   '다',
#   '서운',
#   '하',
#   '다'],
#  ['내용', '이', '이상해'],
#  ['몬스터', '주식회사', '3D', '재밌', '게', '보', '아다'],
#  ['내용전개', '가', '너무나', '느리', '다'],
#  ['소재',
#   '는',
#   '흥미',
#   '를',
#   '끌',
#   '지',
#   '말',
#   'ㄴ',
#   '이야기',
#   '전개',
#   '가',
#   '투박',
#   '하',
#   '어서',
#   '몰입',
#   '이',
#   '안되',
#   '는군'],
#  ['절대', '보지마', '이', '라', '쓰레기', '영화'],
#  ['중국인',
#   '특유',
#   '의',
#   '과장',
#   '허풍',
#   '있',
#   '어',
#   '보이',
#   '려고',
#   '안간힘',
#   '쓰',
#   'ㄴ',
#   '노력',
#   '은',
#   '가상',
#   '하',
#   '어',
#   '나',
#   '아',
#   '고증',
#   '과',
#   '현실감',
#   '떨',
#   '어',
#   '지',
#   '는',
#   '설정',
#   '이',
#   '거북',
#   '스럽',
#   '다',
#   '도대체',
#   '그',
#   '들',
#   '은',
#   '왜',
#   '이렇',
#   '게',
#   '까지',
#   '스스로',
#   '를',
#   '과대포장',
#   '하',
#   '는',
#   '것',
#   '이',
#   'ㄴ지'],
#  ['그냥',
#   '불법체류',
#   '이',
#   '자',
#   '때려잡',
#   '는',
#   '영화',
#   '이',
#   '면',
#   '좋았을텐데무슨',
#   '우상화',
#   '를',
#   '만들',
#   'ㄴ다',
#   '고',
#   '미국',
#   '의',
#   '따뜻한',
#   '설정',
#   '이',
#   '건',
#   '뭥미'],
#  ['2년',
#   '의',
#   '삶',
#   '속',
#   '에',
#   '주인공',
#   '의',
#   '생애',
#   '가',
#   '전부',
#   '드러나',
#   'ㄴ',
#   '듯',
#   '하',
#   '다'],
#  ['별점10점가', '이', '자'],
#  ['별', '로이', '다'],
#  ['보', 'ㄴ지', '꽤', '지나', 'ㄴ', '후', '에', '남기지만재미있었음'],
#  ['아니', '이', '이', '게', '왜', '9점', '대', '일', 'ㄹ까'],
#  ['10년',
#   '이',
#   '지나',
#   '아',
#   '다시',
#   '보',
#   '게',
#   '되',
#   'ㄴ',
#   '영화',
#   '다시봐도',
#   '그',
#   '순수',
#   '하',
#   'ㄴ',
#   '사랑',
#   '에',
#   '감동',
#   'ㅠㅠ',
#   '숀펜',
#   '의',
#   '연기또한',
#   '甲'],
#  ['올레',
#   '에',
#   '공짜로있길래',
#   '보',
#   '아ㅁ',
#   'ㅋㅋ',
#   '헐',
#   'ㄹ',
#   '스토리',
#   '가',
#   '문제가아니',
#   '이',
#   '라',
#   '연기자들',
#   '이',
#   '전혀',
#   '배역',
#   '이랑',
#   '어울리',
#   '지',
#   '않',
#   '음',
#   '그리고',
#   '상대배우들',
#   '하고',
#   '다',
#   '따로',
#   '노는거같음',
#   '이',
#   '이',
#   '건',
#   '연기자들',
#   '도',
#   '문제',
#   '있',
#   '음',
#   '보',
#   '아는',
#   '진심',
#   '완전',
#   '별',
#   '로이',
#   'ㅁ',
#   '라미란하',
#   '이',
#   '고',
#   '아들',
#   '이',
#   '젤',
#   '보',
#   'ㄹ',
#   '만',
#   '하',
#   '었음'],
#  ['너무',
#   '욕심',
#   '이',
#   '많',
#   '아ㄴ',
#   '영화',
#   '어느',
#   '한',
#   '쪽',
#   '만이라도',
#   '제대로',
#   '보',
#   '이',
#   '어',
#   '주',
#   '었다면'],
#  ['아', '빵점'],
#  ['베댓', '이', '말', '을', '아주', '잘써놨', '네'],
#  ['아주', '모자라', '아', '지', 'ㄴ', '않', '다'],
#  ['영화',
#   '도둑들',
#   '이나',
#   '뫼비우스',
#   '하',
#   '고',
#   '같',
#   '은',
#   '나라',
#   '에서',
#   '만들어졌다는',
#   '게',
#   '믿어지',
#   '냐'],
#  ['온몸', '이', '찌릿짜릿', '나두', '용기', '를', '가', '아', '지', '어야지'],
#  ['정말재미', '있', '고', '교훈적', '이', 'ㄴ', '영화', '이', '네요'],
#  ['당시',
#   '의',
#   '상황',
#   '과',
#   '주제',
#   '를',
#   '주입식',
#   '이',
#   '아니',
#   'ㄴ',
#   '긴장감',
#   '있',
#   '고',
#   '재밌',
#   '게',
#   '전하',
#   '는',
#   '작품'],
#  ['케이블', '에서', '그', '만', '나', '아', '오', '아', '주', '었으면'],
#  ['다르덴이냐리투차이밍량',
#   '이',
#   '하',
#   '어',
#   '나',
#   '아',
#   '안섞인채',
#   '짬뽕',
#   '그릇',
#   '에',
#   '담기',
#   '어',
#   '있',
#   '다'],
#  ['여',
#   '이',
#   '군',
#   '잼',
#   '없',
#   '음',
#   '뭐하',
#   '는',
#   '것',
#   '이',
#   'ㄴ지',
#   'ㅡㅡ잼없음',
#   '엠비씨',
#   '다잼없음',
#   '질린다이제'],
#  ['좋', '구나'],
#  ['한석규',
#   '김혜수',
#   '연기',
#   '만',
#   '돋보이',
#   'ㄴ',
#   '영화',
#   '어딘지',
#   '모르',
#   '게',
#   '많',
#   '이',
#   '어설프',
#   'ㄴ',
#   '영화'],
#  ['솔직히',
#   '에볼라바이러스',
#   '가',
#   '떠들석해서',
#   '보게된영화',
#   '이',
#   'ㄴ데',
#   '작품성',
#   '이나',
#   '어떤면에서',
#   '도',
#   '20',
#   '여',
#   '년',
#   '전',
#   '영화라',
#   '이',
#   '고',
#   '보',
#   '기',
#   '엔',
#   '믿기힘들정도',
#   '로',
#   '정말',
#   '잘만들었다고본다',
#   '마지막후반부',
#   '가',
#   '살짝',
#   '아쉽긴하',
#   '이',
#   '지만',
#   '이정도',
#   '이',
#   '면',
#   '수작',
#   '이라이',
#   '고',
#   '보',
#   'ㄴ다',
#   '시간',
#   '이',
#   '아깝지않은영화'],
#  ['보', 'ㄹ', '만', '하', '어'],
#  ['재미있', '다', '고', '허풍', '떨', '지', '마세요'],
#  ['용가리', '진짜짱짱맨이닼'],
#  ['이',
#   '영화',
#   '를',
#   '이제',
#   '서야',
#   '보',
#   '다니',
#   '감히',
#   '내',
#   '인생',
#   '최고',
#   '의',
#   '영화중',
#   '하나',
#   '로',
#   '꼽',
#   '을',
#   '수',
#   '있',
#   '을',
#   '만',
#   '하',
#   'ㄴ',
#   '작품',
#   '어떻',
#   '게',
#   '살',
#   '아',
#   '하',
#   'ㄹ지',
#   '나',
#   '를',
#   '위하',
#   'ㄴ',
#   '고민',
#   '을',
#   '한번',
#   '더',
#   '하',
#   '게',
#   '되',
#   '는',
#   '시간',
#   '그리고',
#   '모',
#   '이',
#   '건',
#   '프리먼',
#   '은',
#   '나이',
#   '가',
#   '들',
#   '어도',
#   '여전히',
#   '섹시',
#   '하',
#   '다'],
#  ['작가가별로다',
#   '내용이진짜별로',
#   '이',
#   'ㅁ',
#   '맨날그냥기대하',
#   '이',
#   '고',
#   '재방송',
#   '하',
#   '면',
#   '혹시나하고봐줘',
#   '도',
#   '답없다진짜'],
#  ['명작',
#   '도',
#   '이런',
#   '명작',
#   '이',
#   '있',
#   '을까',
#   '싶',
#   '다',
#   '보',
#   '고',
#   '또',
#   '보',
#   '아',
#   '여운',
#   '이',
#   '남',
#   '는',
#   '영화'],
#  ['아',
#   '진짜',
#   '조금',
#   '만',
#   '더',
#   '손',
#   '좀',
#   '보',
#   '면',
#   '왠만한',
#   '상업',
#   '영화',
#   '못지',
#   '않',
#   '게',
#   '퀄리티',
#   '쩔',
#   '게',
#   '만들',
#   '어',
#   '지',
#   'ㄹ',
#   '수',
#   '있',
#   '었는데',
#   '아쉽',
#   '네',
#   '요',
#   '그래도',
#   '충분히',
#   '재미있',
#   '었습니다',
#   '개',
#   '이',
#   'ㄴ',
#   '적',
#   '으로',
#   '조금',
#   '만',
#   '더',
#   '잔인',
#   '하',
#   '게',
#   '더',
#   '자극적',
#   '으로',
#   '노출씬',
#   '도',
#   '화끈하',
#   '이',
#   '게',
#   '하',
#   '었더라면',
#   '어떻',
#   '었을까',
#   '하',
#   '는',
#   '국산영화',
#   '이',
#   '라',
#   '많',
#   '이',
#   '아끼',
#   'ㄴ',
#   '듯',
#   '보',
#   '이',
#   'ㅁ'],
#  ['그만좀', '끌', '고', '이제', '끝내', '라', '지겹', '다', '지겹', '어'],
#  ['아'],
#  ['역시',
#   '드니로',
#   '의',
#   '연기',
#   '는',
#   '일품',
#   '나',
#   '도',
#   '맥스',
#   '가',
#   '샘',
#   '을',
#   '죽이길',
#   '바래',
#   '었다'],
#  ['나름', '괜찮', '은', '작품', '이', 'ㅂ니다'],
#  ['너무', '좋', '은', '영화'],
#  ['정말', '실망', '스러웟음'],
#  ['배우들',
#   '은',
#   '지네들',
#   '안뜨니까',
#   '이런영화',
#   '찍을껀데',
#   '왜',
#   '안뜨는지',
#   '진짜',
#   '모르',
#   '는거야',
#   '면상',
#   '딱',
#   '보',
#   '면',
#   '알',
#   '겠구만',
#   '왜',
#   '지',
#   '이',
#   '네',
#   '자',
#   '이',
#   '시ㄴ들',
#   '은',
#   '모르',
#   'ㄹ까'],
#  ['어린이', '가', '좋아할듯내어릴적', '동심', '은', '멀리', '떠낫', '나보다'],
#  ['무술인', '이', '왜', '총을드', '나'],
#  ['10점'],
#  ['크리스토퍼왈츠', '와', '타란티노', '의', '조합', '이란', 'ㅠㅠ'],
#  ['한국에선유명한편은아니',
#   '이',
#   '지만',
#   '외국',
#   '에선',
#   '상상초월',
#   '하',
#   'ㄴ',
#   '유명',
#   '하',
#   'ㄴ',
#   '영화',
#   '이',
#   'ㅂ니다'],
#  ['오랜만', '에', '재밋는영화봤네요'],
#  ['종방되',
#   '이',
#   '어',
#   '아쉽',
#   '어',
#   '요',
#   '오늘막방',
#   '도',
#   '잘봤어요방송대본',
#   '이',
#   '꽤',
#   '완성도',
#   '있',
#   '다는',
#   '느낌받았고요',
#   '요즘',
#   '드라마들',
#   '의',
#   '막장',
#   '에',
#   '지치',
#   '어',
#   '있',
#   '었는데',
#   '수백향',
#   '은',
#   '정말',
#   '바른드라마였던듯해요악역들',
#   '도',
#   '그리',
#   '심하',
#   '게',
#   '어이없',
#   '지',
#   '도',
#   '않았고요MBC화이팅'],
#  ['평점조절위원회',
#   '에서',
#   '나왔습니다웃음김혜선',
#   '은',
#   '김순정순정',
#   '이',
#   '역할',
#   '이',
#   '제일이다팜므파탈로써그',
#   '정도',
#   '까지',
#   '잘하',
#   '어',
#   '내',
#   'ㄹ',
#   '줄은정말',
#   '의외였어연기20년',
#   '한사람',
#   '에게',
#   '요즘',
#   '사극',
#   '에서',
#   '벌',
#   '어',
#   '지',
#   '고',
#   '있는그녀',
#   '에',
#   '대하',
#   'ㄴ',
#   '연기논란',
#   '은',
#   '왠지',
#   '코미디의한장면',
#   '같음웃음'],
#  ['영화',
#   '끝나',
#   '아',
#   '가',
#   'ㄹ',
#   '때',
#   '쯤',
#   '에',
#   '멍하',
#   '다가',
#   '다보고나',
#   '이',
#   '면',
#   '한마디',
#   '나올거',
#   '이',
#   'ㅁ',
#   'ㅈ같다'],
#  ['공유', '존잘ㅎㅎㅎ'],
#  ['상쾌발랄',
#   '하',
#   'ㄴ',
#   '영화',
#   '이',
#   '다',
#   '말하기',
#   '껄끄런',
#   '성',
#   '이란',
#   '소재',
#   '를',
#   '유쾌',
#   '하',
#   '게',
#   '해설',
#   '하',
#   '었다'],
#  ['소파',
#   '에',
#   '죽',
#   '치',
#   '고',
#   '앉',
#   '아',
#   '지키',
#   '어',
#   '보',
#   'ㄹ',
#   '이유',
#   '가',
#   '없',
#   '는',
#   '작품'],
#  ['로큰롤'],
#  ['주되',
#   'ㄴ',
#   '타겟',
#   '이',
#   '어린이',
#   '이',
#   '니',
#   '일반적',
#   '이',
#   'ㄴ',
#   '논리',
#   '가',
#   '통하',
#   '지',
#   '않',
#   '는',
#   '거',
#   '은',
#   '알',
#   '겠다',
#   '하',
#   '지만',
#   '게임',
#   '은',
#   '흥미',
#   '롭',
#   '지',
#   '않',
#   '고',
#   '요원',
#   '이',
#   '라는',
#   '주인공',
#   '이',
#   '너무',
#   '무능력',
#   '하',
#   '어서',
#   '별로',
#   '재미',
#   '없',
#   '다',
#   'CG',
#   '배경',
#   '도',
#   '거슬리',
#   'ㄴ다'],
#  ['뮤지컬',
#   '영화',
#   '이',
#   'ㄴ데',
#   '사운드',
#   '녹음',
#   '엉망',
#   '남주',
#   '는',
#   '추',
#   'ㅁ',
#   '도',
#   '못추',
#   '이',
#   '고',
#   '내용',
#   '은',
#   '뻔하',
#   'ㄹ',
#   '뻔',
#   '주인공들',
#   '목소리',
#   '도',
#   '너무',
#   '안어울리',
#   '이',
#   '고',
#   '어제',
#   'CGV',
#   '에서',
#   '뛰',
#   '어',
#   '나',
#   '아',
#   '가',
#   '려다',
#   '참았습니다진심',
#   '말',
#   'ㄹ',
#   '리',
#   '이',
#   '고',
#   '싶',
#   '습니다',
#   '영국',
#   '의',
#   '저예산',
#   'DVD',
#   '용',
#   '영화뮤지컬영화',
#   '아니',
#   'ㅂ니다',
#   '.',
#   '맘마미아',
#   '110',
#   '도',
#   '안',
#   '되',
#   'ㅁ'],
#  ['어린나이',
#   '에',
#   '보',
#   '아ㅁ',
#   '에도',
#   '끄',
#   '어',
#   '나',
#   '아',
#   '좋',
#   '아',
#   '하',
#   '었던',
#   '로맨틱코미디'],
#  ['게이물', '이', 'ㄴ', '줄', '모르', '고', '보', '아네'],
#  ['알바는꺼저', '이', '라'],
#  ['이',
#   '영화',
#   '머임내',
#   '가',
#   '왜',
#   '받',
#   '아',
#   '보',
#   '아ㄹ까',
#   '그것',
#   '이',
#   '알고싶다',
#   '이',
#   '영화',
#   '는',
#   '배우들',
#   '과',
#   '스텝들',
#   '이',
#   '감독',
#   '의',
#   '꼭두각시',
#   '이',
#   '었음'],
#  ['4대2라니최악'],
#  ['정말', '아름답', '은', '영화', '입', '니다'],
#  ['자극적',
#   '이',
#   'ㄴ',
#   '것',
#   '에',
#   '익숙해지',
#   'ㄴ',
#   '현대인',
#   '이',
#   '보',
#   '아',
#   '눈',
#   '을',
#   '떼',
#   '기',
#   '힘들',
#   'ㄴ',
#   '연출력'],
#  ['뻑뻑잘', '읽어볼걸', '나', '도', '당하', '었음'],
#  ['정말',
#   '짜증',
#   '의',
#   '극치',
#   '를',
#   '보여주는영화',
#   '굉장히',
#   '언밸러스한',
#   '느끼',
#   'ㅁ',
#   '뚱뚱하',
#   '어',
#   '고',
#   '못생기',
#   'ㄴ',
#   '남자애',
#   '의',
#   '발연기',
#   '를',
#   '시종일관',
#   '보',
#   '아',
#   '하',
#   '는게',
#   '고역',
#   '이',
#   'ㄴ',
#   '듯',
#   '간간히',
#   '흐르',
#   '어',
#   '나',
#   '아',
#   '오',
#   '는',
#   '잔잔한',
#   '클래식풍',
#   '의',
#   '음악',
#   '조차도',
#   '듣기싫어',
#   '짜증날정도',
#   '로',
#   '상당히',
#   '싫은영화'],
#  ['감동감동ㅜㅜ', '정말', '최고', '이', '네요'],
#  ['별점',
#   '주',
#   '기',
#   '도',
#   '아깝',
#   '네',
#   '요',
#   '얼마나',
#   '내용',
#   '이',
#   '진부한지',
#   '욕',
#   '밖',
#   '에',
#   '안나오네요보',
#   '이',
#   '고',
#   '재밌다',
#   '이',
#   '고',
#   '하',
#   '는',
#   '사람',
#   '초딩들',
#   '이',
#   'ㄴ가',
#   '요',
#   '죄송',
#   '하',
#   '어',
#   '요',
#   '너무',
#   '화가나서아무',
#   '것',
#   '도',
#   '볼',
#   '게',
#   '없',
#   '습니다',
#   '보',
#   '지',
#   '말',
#   '세',
#   '요',
#   '그냥',
#   '티비판짜집기',
#   '한거',
#   '같',
#   '네요'],
#  ['나', '왠만해서', '짜증안내는데_'],
#  ['돼지피먹고',
#   '닭목따',
#   '는',
#   '장면',
#   '에선',
#   '우웩',
#   '역시',
#   '무당',
#   '은',
#   '아무',
#   '나',
#   '하',
#   '는게',
#   '아니',
#   '다',
#   '.'],
#  ['버리', '어'],
#  ['유치', '하고', '지루', '하고', '잠', '이', '오', '아다'],
#  ['3류풍', '판타지', '3점', '만', '가', '아', '지', '어', '가', '아'],
#  ['윤종신',
#   '복귀',
#   '는',
#   '좋',
#   '아지만',
#   '이하늘',
#   '은',
#   '도대체',
#   '왜',
#   '뽑히',
#   '었는지',
#   '알수가없다',
#   '참가자',
#   '실력',
#   '을',
#   '뜨',
#   '어',
#   '지',
#   '기',
#   '전',
#   '에',
#   '심사위원',
#   '인격',
#   '과',
#   '실력',
#   '부터',
#   '쌓',
#   '고',
#   '오시길',
#   '어하어허',
#   '그만좀',
#   '하',
#   '고요'],
#  ['광장한', '작품', '옛날것', '도', '보', '고', '싶', '다'],
#  ['내', '생', '의', '최고', '의', '영화'],
#  ['어린시절',
#   '너무',
#   '무섭',
#   '고',
#   '재미있',
#   '게',
#   '보',
#   '아ㄴ',
#   '추억',
#   '의',
#   '판타지영화절대',
#   '나쁘',
#   'ㄴ',
#   '짓',
#   '은',
#   '금물지옥가요'],
#  ['기존',
#   '멜로영화',
#   '형식',
#   '을',
#   '탈피',
#   '하',
#   '려고',
#   '하',
#   '었으나',
#   '감정',
#   '의',
#   '절제',
#   '가',
#   '지나치',
#   '어',
#   '너무',
#   '담백한',
#   '영화'],
#  ['나',
#   'ㄴ',
#   '사랑비',
#   '서준에',
#   '이',
#   '게',
#   '쏙',
#   '빠지',
#   '어',
#   '버리',
#   '었네',
#   '123초',
#   '만에',
#   '쏙ㅋㅋ난',
#   '절대잊지도않고후회도안할거',
#   '야'],
#  ['이영화를보',
#   '이',
#   '니까',
#   '교훈',
#   '을',
#   '주',
#   '네',
#   '요',
#   '나',
#   '도',
#   '남은인생',
#   '을',
#   '화',
#   '이',
#   '리어',
#   '하',
#   '게',
#   '살아야겟다',
#   '말',
#   '밖에',
#   '안나오',
#   '이',
#   '네요'],
#  ['나름',
#   '추억',
#   '에',
#   '젖어들고',
#   '좋았음ㅋㅋ아무생각없',
#   '이',
#   '가볍',
#   '게',
#   '보',
#   '고',
#   '오',
#   '기',
#   '추천요'],
#  ['단순', '하', 'ㄴ', '싸이코물', '을', '벗', '어', '나', 'ㄴ'],
#  ['이',
#   '이',
#   '게',
#   '14년도',
#   '에',
#   '만들',
#   '어',
#   '지',
#   'ㄴ',
#   '것',
#   '이',
#   'ㄴ가',
#   '요',
#   '아니',
#   '면',
#   '예전',
#   '에',
#   '만든거',
#   '다시개봉한건가요ㅠ너무',
#   '허접해요',
#   'ㅠ'],
#  ['널',
#   'ㅁ',
#   '사랑',
#   '스럽',
#   '은',
#   '영화',
#   '이',
#   '다',
#   'ㅠㅠ',
#   '1보',
#   '이',
#   '고',
#   '2',
#   '연이',
#   '어',
#   '보',
#   '아다',
#   '널',
#   'ㅁ',
#   '귀엽',
#   '어',
#   'ㅠㅠ'],
#  ['청춘',
#   '영화만',
#   '이',
#   '주',
#   'ㄹ',
#   '수',
#   '있',
#   '는',
#   '감성',
#   '이',
#   '넘치',
#   '어',
#   '나',
#   'ㄴ다',
#   '이',
#   '순간',
#   '지나',
#   '아',
#   '가',
#   '면',
#   '다시',
#   '돌',
#   '아',
#   '오',
#   '지',
#   '않을테지만',
#   '그',
#   '순간',
#   '만큼은',
#   '무한',
#   '하',
#   'ㄹ',
#   '젊음',
#   '이',
#   '주',
#   'ㄹ',
#   '수',
#   '있',
#   '는',
#   '그러',
#   'ㄴ',
#   '감성'],
#  ['TV', '용', '건담', '시리즈', '중', '에서', '아직', '까지도', '최고봉'],
#  ['개콘', '은', '요즘', '가', 'ㄹ수록', '코너들', '이', '다노잼', '이', '고', '웃음이안난다'],
#  ['사다코', '의', '한', '이', '서리', 'ㄴ', '우물펀치ㅜㅜ', '감동'],
#  ['후세',
#   '와',
#   '사랑',
#   '하',
#   '게',
#   '되',
#   'ㄴ',
#   '결정적',
#   '계기',
#   '그시간',
#   '이',
#   '표현',
#   '되',
#   '지',
#   '않',
#   '아며',
#   '시람',
#   '의',
#   '생명',
#   '을',
#   '빼앗아야만하는이유등',
#   '을',
#   '시노',
#   '가',
#   '출현',
#   '하',
#   '는',
#   '연극으',
#   '로',
#   '더',
#   '알리',
#   '어',
#   '주',
#   '었으면',
#   '하',
#   '는',
#   '생각이든다',
#   '또한',
#   '시노',
#   '가',
#   '얼마나',
#   '본능을절제히',
#   '이',
#   '면서',
#   '시랑',
#   '을',
#   '하',
#   '려고',
#   '노력',
#   '하',
#   '는',
#   '지',
#   '를',
#   '더',
#   '보이',
#   '어',
#   '주',
#   '었다면',
#   '좋',
#   '아ㄹ',
#   '뻔',
#   '하',
#   '었다'],
#  ['새벽시간',
#   '에',
#   '하',
#   '는',
#   '일본',
#   '영화들',
#   '은',
#   '전부',
#   '개졸작이다일본영화원래',
#   '다이',
#   '이',
#   '래'],
#  ['강수연', '의', '나가있어그리', '이', '고', '최정원', '의', '신음신'],
#  ['아정말', '김혜성', '너무', '예쁘', '네', '요', '이현진', '도', '웃', '는', '것', '정말하'],
#  ['가발', '쓰', '어', '고', '싶', '다'],
#  ['화려한여정이인상깊어욬ㅋ재밋어욬ㅋ배두나연기정말잘해욬'],
#  ['10대들', '을', '위하', 'ㄴ', '성적', '호', '이', '기', '이', '시ㅁ', '영화'],
#  ['감동적', '이', 'ㄴ', '영화'],
#  ['이', '이', '건', '말', '이', '필요', '없', '다', '그냥', '닥치', '고', '보', '아'],
#  ['각기', '다른', '사람', '들', '의', '재밌고', '멋지', 'ㄴ', '사랑영화'],
#  ['역시',
#   '미국드라마',
#   '의',
#   '파워',
#   '정말',
#   '알',
#   'ㄹ',
#   '수',
#   '없',
#   '는',
#   '그',
#   '미묘함',
#   '까지',
#   '사로잡',
#   '어',
#   '버리',
#   '었다',
#   '최고'],
#  ['너무너무', '훈훈', '하', '네요'],
#  ['이거', '응답하라', '에서', '은지원원', '도', '스스로', '욕', '하', '지', '않앗', '나', 'ㅋㅋㅋㅋ'],
#  ['아',
#   '너무',
#   '웃',
#   '기',
#   '이',
#   '고',
#   '배꼽',
#   '빠지',
#   'ㄹ',
#   '뻔',
#   '하',
#   '었네',
#   '내',
#   '컴',
#   '에',
#   '이',
#   '영화',
#   '있',
#   '는데'],
#  ['구성',
#   '이',
#   '상당히',
#   '부',
#   '이',
#   '시ㄹ',
#   '한',
#   '영화',
#   '역시',
#   '네이버',
#   '평점',
#   '은',
#   '믿',
#   '을',
#   '수',
#   '없',
#   '다'],
#  ['장끌로드',
#   '의',
#   '몰락',
#   '을',
#   '가',
#   '아',
#   '지',
#   '어',
#   '오',
#   'ㄴ',
#   '오우삼',
#   '헐리우드',
#   '작품중',
#   '가장',
#   '재미',
#   '없',
#   '었던',
#   '졸작'],
#  ['언제적', '영웅본색', '연출', '이', 'ㄴ지', '현실성', '제로', '이', 'ㄴ', '영화'],
#  ['작은거',
#   '하나',
#   '에도',
#   '설레',
#   '어',
#   '하',
#   '었던',
#   '학창시절',
#   '그때',
#   '그느낌',
#   '을',
#   '다시',
#   '느껴볼수있는시간이었다',
#   '장면',
#   '하나',
#   '하나',
#   '대사',
#   '하나',
#   '하나',
#   '배경음악',
#   '하나',
#   '하나',
#   '버릴',
#   '게',
#   '없',
#   '는',
#   '드라마'],
#  ['진심', '재미', '없', '는데', '너무', '평점', '높', '아', '화나', 'ㅁ'],
#  ['더럽',
#   '게',
#   '재미',
#   '없',
#   '다',
#   '어떤',
#   '형태',
#   '로도',
#   '오',
#   '아',
#   '닿',
#   '지',
#   '않',
#   '는',
#   '허무',
#   '하고',
#   '완벽히',
#   '지루',
#   '하',
#   'ㄴ',
#   '영화',
#   '이',
#   '고',
#   '영양',
#   '가',
#   '하',
#   '어',
#   '나',
#   '아',
#   '없',
#   '는',
#   '영화',
#   '이',
#   '다'],
#  ['이승기', '정말', '연기', '잘하', '는', '조연들', '도', '연기', '정말', '잘하', '고'],
#  ['현실', '은', '꾸', 'ㅁ', '꿈', '은', '현실'],
#  ['오늘',
#   '현충일특집프로',
#   '로',
#   '보',
#   '게',
#   '되',
#   '었습니다',
#   '1963년도',
#   '의',
#   '매우',
#   '훌륭',
#   '하',
#   'ㄴ',
#   '작품',
#   '이',
#   'ㅂ니다'],
#  ['판의미로', '와', '동급', 'trash', 'of', 'the', 'trash'],
#  ['제대', '하고', '보', '니까', '더', '재밌네요', 'ㅋㅋㅋㅋ'],
#  ['영화',
#   '를',
#   '보',
#   '는',
#   '것',
#   '만으로도',
#   '마음',
#   '의',
#   '휴가',
#   '를',
#   '다니',
#   '어',
#   '오',
#   'ㄴ',
#   '느낌소박',
#   '하',
#   '어',
#   '지',
#   '고',
#   '잔잔',
#   '하',
#   '지',
#   '말',
#   'ㄴ',
#   '지루하지않은그래서',
#   '다시',
#   '보',
#   '고',
#   '싶',
#   '은',
#   '영화햇살가득',
#   '하',
#   'ㄴ',
#   '비이',
#   '의',
#   '부엌',
#   '과',
#   '요리',
#   '도',
#   '인상적'],
#  ['코믹한', '건', '좋', '아ㄴ데', '짜임새', '가', '너무', '허술', '하', '다'],
#  ['1996년',
#   '그때',
#   '당시',
#   '에는',
#   '우리',
#   '나라',
#   '에',
#   '이런',
#   '판타지',
#   '로맨스',
#   '가',
#   '없',
#   '었다',
#   '아직',
#   '도',
#   '신현준',
#   '의',
#   '황장군',
#   '연기',
#   '는',
#   '음',
#   '괜찮',
#   '네',
#   'ㅎㅎ한석규',
#   '의',
#   '전성시대',
#   '가',
#   '열리',
#   'ㄴ',
#   '영화',
#   '이때',
#   '한석규',
#   '한테',
#   '뿅',
#   '가',
#   '아다'],
#  ['일단', '재생', '하', '면', '괴물', '같', '은', '서스펜스', '귀신', '같', '은', '흡입력'],
#  ['하진짜',
#   '댓글보',
#   '이',
#   '고',
#   '한번쯤볼만한',
#   '영화인거같아서봤지만',
#   '기가찬다이게무슨버킷리스트인',
#   '가',
#   '죽기직전',
#   '에',
#   '소원들어주',
#   '이',
#   '기',
#   '내',
#   '어',
#   '가',
#   '아',
#   '보',
#   '기',
#   '엔',
#   '죽기직전',
#   '에',
#   '막',
#   '살',
#   '자',
#   '인거같다',
#   '감동도',
#   '없',
#   '고',
#   '진짜',
#   '버킷리스트',
#   '란',
#   '영화',
#   '에',
#   '발톱',
#   '에',
#   '때',
#   '만큼도',
#   '못따라가는쓰레기영화',
#   '완존실망'],
#  ['이시간좀밝고긍정적인드라마보고싶어서보긴보는데오버하는연기들이거슬리네요연기인게너무표나요홍혜정역이그나마도후련기도하고시원하고나머진다들답답하네요낼월요일인데해피한것만보',
#   '이',
#   '고',
#   '싶',
#   '네요'],
#  ['정치인', '의', '모순', '이', 'ㄴ가', '정치범', '의', '모순', '인가'],
#  ['어떻', '게', '이런', '상상', '을', '대단', '하', '다'],
#  ['좀',
#   '어렵',
#   '기',
#   '도',
#   '하',
#   '고',
#   '전쟁',
#   '에',
#   '대하',
#   'ㄴ',
#   '묘사',
#   '가',
#   '잘',
#   '모르',
#   '겠다'],
#  ['일본에서10주년',
#   '극장판만드는데',
#   '우리나라',
#   '에선',
#   '10주년',
#   '으로',
#   '재개봉하니',
#   '이',
#   '건',
#   '좀',
#   'ㅄ',
#   '아니',
#   'ㅁ'],
#  ['한대희',
#   '가',
#   '개그콘서트본다',
#   '이',
#   '고',
#   '내전화끊음개그콘서트',
#   '없애',
#   '어',
#   '주',
#   '세',
#   '요',
#   'ㅡㅡ'],
#  ['한물', '가', 'ㄴ', '동서양', '두', '배우', '의', '싸움판'],
#  ['푸하하하', '이거', '기대', '안하', '었지만', '역시', '나', '구만ㅋ'],
#  ['세계최초', '의', '반공', '애니매이션', '이', '라는', '역사적', '가치', '가', '있', '다'],
#  ['감각적인시각으로바라보는색다른느낌의사랑문학적', '이'],
#  ['엄마',
#   '는',
#   '무',
#   '이',
#   '고',
#   '하',
#   'ㄴ',
#   '지',
#   '딸',
#   '을',
#   '감옥살',
#   '이',
#   '시키',
#   '어',
#   '시키',
#   '어',
#   '이해',
#   '안',
#   '되',
#   '어요'],
#  ['이영화는제발', '책을보세여감독', '이', '미친겁니다이따위', '로', '만들어놓고화', '가', '날정', '도', 'ㅡㅡ'],
#  ['신나', '는', '흑인음악', '과', '아이스', '큐브', '뿐', '남', '는게', '없', '다'],
#  ['드럽',
#   '게',
#   '재미',
#   '없',
#   '네',
#   '시간',
#   '이',
#   '돈',
#   '이',
#   '다',
#   '내',
#   '시간',
#   '은',
#   '어쩌',
#   'ㄹ',
#   '것',
#   '이',
#   'ㄴ데'],
#  ['그저', '한마디', '뿐', '알리시', '아'],
#  ['진짜', '생생하', '게', '느끼', 'ㄹ', '수', '있', '었다'],
#  ['재밌는데', '평점', '이', '이상', '하', '어다', '싶', '을', '정도', '로', '낮', '다'],
#  ['옥소리',
#   '프로필',
#   '사진',
#   '에',
#   '1점남기',
#   '이',
#   '고',
#   '가',
#   'ㅂ니다',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋ완전',
#   '대박',
#   '이',
#   '다',
#   '진짜',
#   '아우',
#   '짜증',
#   '나'],
#  ['드라마', '너무', '재밓당'],
#  ['아진짜너무좋아요ㅜㅜ짱짱'],
#  ['연기', '굿'],
#  ['이런', '영화', '다시', '는', '안나오겠지그때', '시절', '을', '잘나타내주었던거같아요', 'ㅎㅎ'],
#  ['중간정도', '부터', '보', '아ㄴ데', '도', '끄', '어', '나', '아', '대단', '하', '군요'],
#  ['콩', '은', '끄', '어야', '제', '맛', '콩', '은', '끄', '어야', '제', '맛'],
#  ['이적', '의', '소설', '재미', '없', '다'],
#  ['액션영화',
#   '가',
#   '아니다범죄',
#   '느와르',
#   '영화',
#   '이',
#   '다',
#   '헐',
#   '나',
#   '범죄',
#   '느와르',
#   '영화',
#   '로서도',
#   '실패작'],
#  ['뭔가알수없는매력에빠져드', '는', '영화'],
#  ['모녀',
#   '를',
#   '토막살해한',
#   '살',
#   '이',
#   'ㄴ',
#   '자',
#   '가',
#   '부성애',
#   '이',
#   '라니',
#   '말',
#   '이',
#   '되',
#   '나',
#   '감동',
#   '받',
#   '은',
#   '사람들',
#   '본인들',
#   '이',
#   '피해자',
#   '가',
#   '되',
#   '도',
#   '감동',
#   '받',
#   '아다',
#   '고',
#   '하',
#   'ㄹ',
#   '수',
#   '있',
#   '을까',
#   '진심',
#   '묻',
#   '고',
#   '싶',
#   '습니다'],
#  ['재밌는데', '평점', '이', '왜', '이렇', '게', '구리', '이', '지'],
#  ['아',
#   'OOO',
#   '기',
#   '이걸',
#   '보',
#   'ㄴ',
#   '내눈',
#   '이',
#   '아깝',
#   '다',
#   'ㅡㅡ',
#   '진짜',
#   '아놔',
#   '진짜',
#   'OOO기명작',
#   '이',
#   '네요'],
#  ['필름값', '이', '아깝다재미', '더럽게없다2점부터', '점수준것들', '매미', 'OO'],
#  ['뜨', '어', '보', '고', '싶', '은', '데', '어디', '서', '보', '이', '죠'],
#  ['영화', '재미있드만', 'ㅎㅎ'],
#  ['남주인공',
#   '연기력',
#   '안습이네요',
#   '혀짧',
#   '은',
#   '소리',
#   '듣',
#   '기',
#   '도',
#   '너무',
#   '힘들',
#   '었네',
#   '요',
#   '매니저역활분',
#   '이',
#   '남주인공하는게',
#   '훨',
#   '좋',
#   '았겠다는',
#   '생각',
#   '이',
#   '들정',
#   '도',
#   '영화',
#   '자체',
#   '는',
#   '적당히',
#   '보',
#   'ㄹ',
#   '만',
#   '하',
#   'ㅂ니다'],
#  ['3점', '이', '딱', '액션스릴러', '이', 'ㄴ데', '액션', '과', '스릴', '이', '없', '다'],
#  ['완전', '스토리', '도', '엉망이구', '완전', '비추ㅜ'],
#  ['OOO', '영화', '뭘전달하려는지모르겠네', '오글거', '이', '리', '고'],
#  ['좋은영화'],
#  ['더빙', '이', '이상해요할머니', '는', '월래익숙한', 'ㄷㅔ'],
#  ['이', '이', '게', '2편', '이', '나', '아', '오', '아아'],
#  ['모든게', '2', '씩', '다', '부족했다아니50씩'],
#  ['정말', '말', '그대로', '쇼', '하', '는', '영화'],
#  ['12년',
#   '전',
#   '에',
#   '보',
#   '아',
#   '기억',
#   '이',
#   '나',
#   '아',
#   '지',
#   'ㄹ',
#   '않',
#   '지',
#   '말',
#   'ㄴ',
#   '진개가천카이거',
#   '감독',
#   '이름',
#   '세',
#   '자',
#   '는',
#   '기억해',
#   '두',
#   '이',
#   '었던'],
#  ['정은지',
#   '언니',
#   '연기',
#   '잘하구노래',
#   '도',
#   '잘부르시',
#   '이',
#   '고',
#   '마지막회',
#   '웃',
#   '으면서',
#   '즐겁',
#   '게',
#   '보',
#   '아ㅂ니다',
#   '트로트',
#   '의',
#   '연인'],
#  ['이', '이', '게', '웃기', '어'],
#  ['망', '하', 'ㅁ'],
#  ['아이',
#   '의',
#   '시선',
#   '으로',
#   '보',
#   '는',
#   '전쟁',
#   '보',
#   '는',
#   '내',
#   '어',
#   '내',
#   '어',
#   '가슴',
#   '이',
#   '먹먹했다',
#   '는'],
#  ['사람',
#   '들',
#   '이',
#   '재미',
#   '없',
#   '다',
#   '고',
#   '하',
#   '어서',
#   '레알',
#   '기대',
#   '안하',
#   '었는데',
#   '생각',
#   '보다',
#   '보',
#   'ㄹ',
#   '만',
#   '하',
#   'ㅁ',
#   '근데',
#   '여자애',
#   '랑',
#   '복',
#   '순',
#   '이랑',
#   '다투',
#   '는',
#   '장면',
#   '그것',
#   '은',
#   '굳이',
#   '없',
#   '어도',
#   '되',
#   '었다',
#   '고',
#   '생각',
#   '하',
#   'ㅁ',
#   '몰입',
#   '도',
#   '겁',
#   '나',
#   '없애',
#   '고',
#   '어색',
#   '하',
#   '어',
#   '보이',
#   '었음'],
#  ['설정',
#   '이',
#   '연속극',
#   '같',
#   '은',
#   '느끼',
#   'ㅁ',
#   '이',
#   '들',
#   'ㄴ다',
#   '하',
#   '지만',
#   '배우들',
#   '의',
#   '연기',
#   '가',
#   '뛰어나',
#   '다'],
#  ['여주인공', '인터뷰할때', '지루해죽는줄알았음', 'ㅡㅡ', '그냥저냥', '킬링타임용', '스릴러'],
#  ['전미',
#   '박스',
#   '오피스1위',
#   'ㅋㅋ',
#   '그냥',
#   '몰',
#   '아',
#   '주',
#   '기',
#   '하',
#   '는',
#   '것',
#   '이',
#   'ㄴ가',
#   '어떻',
#   '게',
#   '이런영화',
#   '가',
#   '1위',
#   '를',
#   '하',
#   '지',
#   '옛날',
#   '8090년대',
#   '우뢰매수준',
#   '의',
#   '물폭탄싸움이네',
#   'ㅋㅋ',
#   '손',
#   '에서',
#   '빔나가',
#   '나',
#   '손',
#   '에서',
#   '물폭탄',
#   '나가',
#   '아',
#   '나',
#   '아',
#   '다를게',
#   '뭐',
#   '이',
#   '지'],
#  ['감독', '이', '여자다보', '이', '니', '기량', '이', '많', '이', '딸리', '네'],
#  ['또', '보', '고', '또', '울', '었다'],
#  ['이런',
#   '영화',
#   '는',
#   '하나',
#   '의',
#   '개연성',
#   '만',
#   '없',
#   '어도',
#   '허무',
#   '하',
#   '게',
#   '만들',
#   '어',
#   '버리',
#   'ㄴ다',
#   '조디포스터',
#   '의',
#   '이쁘',
#   'ㄴ',
#   '모습',
#   '만',
#   '남',
#   '을',
#   '영화'],
#  ['굳굳'],
#  ['스토리',
#   '도',
#   '말',
#   '이',
#   '안되',
#   '고',
#   '개막장',
#   '사랑이야기',
#   '도',
#   '아니',
#   '예요',
#   '이걸보고계',
#   '이',
#   '시ㄴ다면',
#   '당신',
#   '의',
#   '시간과돈',
#   '을',
#   '아낀거예요휴',
#   '그래도',
#   '보',
#   'ㄴ다면',
#   '호구'],
#  ['네놈', '을', '살리', '어', '두', '기', '엔', '쌀', '이', '아깝', '어', '세기', '의', '명대사'],
#  ['평점',
#   '이',
#   '너무',
#   '높',
#   '다',
#   '전혀',
#   '재미있',
#   '지',
#   '않',
#   '아다',
#   '쓸데없이',
#   '말',
#   '만',
#   '많',
#   '음',
#   '이런',
#   '류',
#   '의',
#   '영화',
#   '는',
#   '조연',
#   '들',
#   '의',
#   '뒷받침',
#   '이',
#   '중요',
#   '하',
#   'ㄴ데',
#   '조연',
#   '들',
#   '의',
#   '내용자체',
#   '가',
#   '전혀',
#   '없',
#   '음',
#   '또한',
#   '여배우',
#   '도',
#   '별로',
#   '매력',
#   '없',
#   '었다',
#   '이틀전',
#   '에',
#   '저스트고위드잇',
#   '의',
#   '애니스톤',
#   '을',
#   '보',
#   '고',
#   '이',
#   '영화',
#   '를',
#   '보',
#   '아',
#   '그러',
#   'ㄴ가',
#   '실망',
#   '하',
#   '었음'],
#  ['맛깔', '나', '는', '드라마'],
#  ['시베리아인', '가', '거기가서', '훈련할때나오', '는', 'ost', '개작살'],
#  ['이',
#   '이',
#   '건',
#   '시종일관',
#   '질질왜',
#   '제목',
#   '이',
#   '야경꾼',
#   '일',
#   'ㄹ',
#   '지',
#   '이',
#   '냐',
#   '고',
#   '지금',
#   '10회',
#   '가',
#   '넘',
#   '어',
#   '가',
#   'ㄴ데',
#   '즉',
#   '2달',
#   '이',
#   '넘',
#   '어',
#   '가',
#   'ㄴ데',
#   '앞',
#   '에서',
#   '누군가',
#   '가',
#   '얘',
#   '이',
#   '기',
#   '하',
#   '더어',
#   '말',
#   'ㄴ',
#   '이거',
#   '100부작',
#   '이',
#   '냐',
#   '고',
#   '그러',
#   '어다',
#   '또',
#   '하',
#   'ㄴ',
#   '순간',
#   '에',
#   '모든걸',
#   '훅진짜',
#   '지루함',
#   '의',
#   '지존'],
#  ['나이들수록', '이해', '가', '가', '는', '영화'],
#  ['ㅠㅠ', '슬픔'],
#  ['장면',
#   '개연성',
#   '도',
#   '없',
#   '고',
#   '아역',
#   '은',
#   '연기',
#   '도',
#   '못하',
#   '고',
#   '무슨',
#   '추노',
#   '에',
#   '나',
#   '아',
#   '오',
#   '는',
#   '민폐언년',
#   '외국판인줄초반만',
#   '그럴싸하',
#   'ㄴ',
#   '저급영화'],
#  ['이', '영화', '정말', '별루예요', '결말', '이', '이상', '하', '어요'],
#  ['딱히', '재미', '는', '없', '네', '요', '킁'],
#  ['송강호',
#   '는',
#   '정말',
#   '연기',
#   '를',
#   '하기위해',
#   '태어나',
#   '아고',
#   '그로인해',
#   '우리',
#   '는',
#   '즐거움',
#   '을',
#   '느끼',
#   'ㄴ다',
#   '역시',
#   '송강호',
#   '는',
#   '연기파',
#   '이',
#   '다'],
#  ['일본영화',
#   '수입',
#   '금지',
#   '시절',
#   '에도',
#   '비디오',
#   '테이프',
#   '로',
#   '돌리',
#   '어',
#   '보',
#   '아ㄴ',
#   '불후',
#   '의',
#   '명작',
#   '아',
#   '그립',
#   '다'],
#  ['살인',
#   '을',
#   '소재',
#   '로',
#   '하',
#   'ㄴ',
#   '영화',
#   '가',
#   '이토록',
#   '재밌',
#   '을',
#   '줄',
#   '이야',
#   '살인',
#   '에',
#   '대하',
#   'ㄴ',
#   '감독',
#   '의',
#   '해석',
#   '이',
#   '정말',
#   '재치',
#   '있',
#   '다',
#   '대',
#   '배우님',
#   '들',
#   '의',
#   '10',
#   '여',
#   '년',
#   '전',
#   '모습',
#   '도',
#   '새롭웠고',
#   'ㅋ',
#   '정말',
#   '유쾌',
#   '하고',
#   '재밌다'],
#  ['누미', '라파스', '신봉선', '닮', '아', '안', '보', 'ㄴ다'],
#  ['케이블', '에서', '그', '만', '좀', '재탕해', '이', '라'],
#  ['멋지',
#   '었다',
#   '정말',
#   '이',
#   '지',
#   '멋지',
#   '다는',
#   '말',
#   '이외',
#   '엔',
#   '하',
#   'ㄹ',
#   '말',
#   '이',
#   '없',
#   '다'],
#  ['98년',
#   '에',
#   '어떻',
#   '게',
#   '이런영화',
#   '가',
#   '만들',
#   '어',
#   '지',
#   '었는지',
#   '의문',
#   '당대',
#   '최고',
#   '의',
#   '영화',
#   '지금봐',
#   '도',
#   '퀄',
#   '에서',
#   '결코',
#   '떨어지',
#   '지',
#   '않',
#   '아요'],
#  ['지금',
#   '이거',
#   '티비',
#   '로',
#   '돌',
#   'ㄴ',
#   '내',
#   '이',
#   '고',
#   '보',
#   '고',
#   '있',
#   '는',
#   '내가한심하',
#   '이',
#   '다'],
#  ['쓰레기', '연예', '이', 'ㄴ', '재기', '의', '장그', '이', '러', '나'],
#  ['굿', '좋', '아'],
#  ['많', '은', '감동', '을', '주', 'ㄴ', '드라마', '이', '다'],
#  ['발로만든영화',
#   '지진나',
#   '서',
#   '주인공',
#   '넘',
#   '어',
#   '지',
#   'ㄴ데',
#   '뒤',
#   '로',
#   '사람들',
#   '유유히',
#   '걸어다니',
#   '고',
#   '있',
#   '음',
#   '발CG',
#   '발연기',
#   '발시나리오',
#   '내용',
#   '도',
#   '정말',
#   '뭐같음',
#   'ㅋㅋㅋ'],
#  ['적당히', '하', '어야지', '언제', '끝나', '는', '것', '인가'],
#  ['잊', '을', '수', '없', '는', '안개낀', '워터루', '다리', '와', '마스코트'],
#  ['곤사토시',
#   '감독',
#   '2010년',
#   '안타깝',
#   '게',
#   '돌',
#   '아',
#   '가',
#   '시어서',
#   '가슴',
#   '이',
#   '먹먹합니다',
#   '정말',
#   '천재적',
#   '이',
#   'ㄴ',
#   '감독',
#   '이',
#   'ㄴ데',
#   '알',
#   'ㅁ',
#   '으로',
#   '가',
#   '시다니',
#   'ㅠㅠ',
#   '이제와서',
#   '다시봐도',
#   '모든',
#   '작품',
#   '이',
#   '대작'],
#  ['많은생각',
#   '을',
#   '하',
#   '게',
#   '되',
#   '었습니다',
#   '예뼈',
#   '이',
#   '지',
#   '고',
#   '싶',
#   '은',
#   '말',
#   'ㅁ',
#   '은',
#   '있',
#   '었지만',
#   '고',
#   '아',
#   '하',
#   '면',
#   '독',
#   '이',
#   '겠네요'],
#  ['아', '츠무구만', '없', '어', '지', '면', '별', '5개줄', '게'],
#  ['어릴땐',
#   '조폭영화',
#   '로',
#   '알',
#   '다가',
#   '나이가들수록',
#   '이',
#   '이',
#   '게',
#   '인생',
#   '이',
#   '구나',
#   '하',
#   '고',
#   '뭉클하',
#   '어',
#   '지',
#   '는',
#   '영화세상',
#   '을',
#   '살',
#   '아',
#   '가',
#   '면',
#   '가',
#   'ㄹ수록',
#   '와닿는게',
#   '많아지네요세상',
#   '은',
#   '비정',
#   '하',
#   '지',
#   '말',
#   'ㄴ',
#   '비정함마져',
#   '도',
#   '따뜻해지',
#   '는게',
#   '친구',
#   '라고'],
#  ['영상', '이', '너무나', '도', '멋지', '다'],
#  ['비디오',
#   '가',
#   '있',
#   '어서',
#   '보',
#   '아ㄴ데',
#   '1997년도인줄모를정도',
#   '로',
#   '잘만들었습니다',
#   '긴장감도',
#   '있',
#   '고'],
#  ['처ㅝ주'],
#  ['2009년',
#   '에',
#   '만들어진것치곤',
#   '재밌음',
#   '영화',
#   '가',
#   '길',
#   '어서',
#   '좀',
#   '다듬',
#   '었으면',
#   '소재',
#   '도',
#   '좋',
#   '고',
#   '몰입감',
#   '도',
#   '기대이상',
#   '매끄럽',
#   '지',
#   '못하',
#   'ㄴ',
#   '부분',
#   '도',
#   '있',
#   '지',
#   '말',
#   'ㄴ',
#   '연기',
#   '는',
#   '둘',
#   '다',
#   '잘하',
#   'ㄴ',
#   '듯'],
#  ['철지난',
#   '조폭',
#   '코미디',
#   '와',
#   '뼈대',
#   '있',
#   '는',
#   '가문',
#   '의',
#   '이야기',
#   '를',
#   '섞',
#   '었지만',
#   '둘',
#   '다',
#   '지루',
#   '하',
#   '어다',
#   '박정아',
#   '를',
#   '비롯',
#   '하',
#   '어',
#   '배우들',
#   '은',
#   '보',
#   '기',
#   '민망',
#   '하',
#   'ㄴ',
#   '연기',
#   '를',
#   '펼치',
#   '고',
#   '기억',
#   '에',
#   '남',
#   '는',
#   '거',
#   '은',
#   '하',
#   '어',
#   '나',
#   '아',
#   '없',
#   '다'],
#  ['군더더기', '없이', '잘', '진행', '되', 'ㄴ데', '재미', '도', '없', '는게', '문제'],
#  ['심심',
#   '하',
#   '어서',
#   '보',
#   '아ㄴ데',
#   '재밌네요',
#   '탑연기',
#   '못할줄알았는데배우포스나',
#   '이',
#   '고',
#   '잘하',
#   '군요'],
#  ['고다미', '괜찮', '음'],
#  ['아', '지대짜증', '아빠', '랑', '봣는데', '민망해', '죽', '는', '줄'],
#  ['0점', '은', '못주', '이', '냐'],
#  ['빠순', '이', '영화', 'ㅋㅋㅋㅋㅋ', 'ㅋㅋ', '훈훈하긔', '재밋쎠'],
#  ['최악', '의', '애니메이션', '지루', '하고', '재미', '없', '고', '스토리', '마저', '진부', '하', '다'],
#  ['좋', '은', '의도', '와는', '다르', '게', '불쾌', '하', 'ㄴ', '표현법'],
#  ['줄리아로버츠', '귀여운연인', '은', '이거', '보다', '5년전꺼', '이', '다'],
#  ['신선', '하', '네'],
#  ['예술가',
#   '로써의',
#   '한',
#   '사람',
#   '의',
#   '인생과당시',
#   '시대적',
#   '상황',
#   '을',
#   '지',
#   'ㄹ',
#   '느끼',
#   'ㄹ',
#   '수',
#   '있',
#   '었던',
#   '명작'],
#  ['관객수',
#   '가',
#   '너무',
#   '아쉽',
#   '은',
#   '영화베테랑',
#   '보다도',
#   '더',
#   '류승완감독',
#   '의',
#   '역작',
#   '이',
#   '고',
#   '더',
#   '강한악역',
#   '이',
#   '다'],
#  ['한창',
#   '핵펭귄',
#   '이',
#   '남북',
#   '거짓평화',
#   '로',
#   '전국민',
#   '을',
#   '속',
#   '이',
#   '던',
#   '때',
#   '만들',
#   '어',
#   '지',
#   'ㄴ',
#   '영화'],
#  ['지금', '티비', '에서', '하', 'ㄴ데', '못', '보', '이', '겠다'],
#  ['여자애', '한명이잘', '못해서몇명이죽는거얔ㅋ답도없닼'],
#  ['성룡', '의', '헐리웃작', '중', '단연', '최고', '이', '지', 'ㅋㅋㅋ'],
#  ['안습'],
#  ['감독', '의', '의도', '를', '전혀', '알아차리', '지', '못하', '었다'],
#  ['하나님이가정을온전히만든다', '진리이신분이만든영화', '눈으로만보지말고마음으로봐', '이', '라'],
#  ['2편', '도', '나름', '흥미진진한데', '핀헤드', '가', '죽', '은게', '좀', '아쉽', '은', '점이랄까'],
#  ['국산',
#   '코미디영화중',
#   '에서',
#   '나',
#   'ㄴ',
#   '신라의달밤',
#   '이',
#   '제일좋았음뭔',
#   '가',
#   '푸근',
#   '하고',
#   '따뜻함'],
#  ['최악', '이', '다', '영화', '보다가', '잠오긴첨', '이', 'ㅁ', '지루해둑을뻔'],
#  ['탄탄', '하', 'ㄴ', '배우들', '될고', '머하', '는', '건지'],
#  ['영화',
#   '가',
#   '점점',
#   '끝',
#   '을',
#   '달리',
#   '어',
#   '가',
#   'ㄹ수록',
#   '몰입도',
#   '가',
#   '더',
#   '높',
#   '아',
#   '지',
#   'ㄴ',
#   '영화',
#   '는',
#   '이번',
#   '이',
#   '처음',
#   '이',
#   '네요'],
#  ['결국',
#   '감독',
#   '자신',
#   '이',
#   '하',
#   '고',
#   '싶',
#   '은',
#   '의견',
#   '을',
#   '지존파',
#   '핑계삼',
#   '아',
#   '하',
#   '려고',
#   '하',
#   'ㄴ',
#   '듯',
#   '지존파',
#   '살인',
#   '은',
#   '정당화',
#   '하고',
#   '정부탓',
#   '이',
#   '였다는사회탓',
#   '이라는'],
#  ['사실여부',
#   '를',
#   '떠나알고왔던',
#   '아더',
#   '와',
#   '너무',
#   '매칭',
#   '이',
#   '안돼더라원탁기사중',
#   '실제',
#   '검술',
#   '최고수',
#   '는',
#   '랜슬롯',
#   '으로',
#   '알',
#   '고',
#   '있는데트리스탄보다',
#   '못하고싸우',
#   '는',
#   '검술',
#   '은',
#   '마치',
#   '중국검술',
#   '흉내낸거',
#   '같',
#   '은게',
#   '그리고',
#   '란슬롯',
#   '이',
#   '실제',
#   '는',
#   '쌍검였나너무',
#   '매칭',
#   '이',
#   '안대',
#   '하튼',
#   'ㅋ기네비어역',
#   '도',
#   '미스'],
#  ['대한민국',
#   '영화',
#   '수준',
#   '의',
#   '평균치',
#   '를',
#   '하락',
#   '시키',
#   '기',
#   '에',
#   '충분한',
#   'C',
#   '급',
#   '영상물'],
#  ['0점', '은', '없', '나'],
#  ['재밌는데'],
#  ['재미', '없', '다', '기대', '완전', '하', '었는데', '완전', '못하', 'ㅁ', '실망'],
#  ['종착역', '없', '는', '인생', '의', '대유', '트레비스', '는', '단지', '흐르', '어', '가', 'ㄴ다'],
#  ['돈', '과', '시간', '이', '아깝', '은', '영화'],
#  ['네러티브',
#   '는',
#   '하',
#   '어',
#   '나',
#   '아',
#   '없',
#   '는',
#   '예쁘',
#   'ㄴ',
#   '음악',
#   '동영상',
#   '취미',
#   '로',
#   '영화만드',
#   '는',
#   '것',
#   '은',
#   '이걸',
#   '로',
#   '끝나길',
#   '잘하',
#   '는',
#   '음악',
#   '에',
#   '올인하길'],
#  ['배우들', '의', '연기', '는', '좋', '아ㄴ데', '뭐', '을', '말', 'ㄹ', '하', '려는', '건지'],
#  ['학위위조성범죄자',
#   '문제자',
#   '들',
#   '만',
#   '모으',
#   '아',
#   '영화찍음',
#   '왜그랬으까',
#   '제작비',
#   '아끼려구',
#   '패자부활전',
#   '하',
#   '냐'],
#  ['솔직히'],
#  ['완전재미있어요애들도보기에알맞는듯'],
#  ['잔인하기', '도', '하', '고', '무서웠어요ㅠ탑', '은', '멋있', '더라구', '요'],
#  ['무섭', '지', '도', '않', '고', '기분', '만', '나쁘', '고', '쩝'],
#  ['군더더기',
#   '없',
#   '는',
#   '깔끔한',
#   '그러나',
#   '강하',
#   'ㄴ',
#   '메세지',
#   '전달',
#   '뜻밖',
#   '의',
#   '참좋',
#   '은',
#   '영화'],
#  ['이',
#   '영화',
#   '는',
#   '최고',
#   '이',
#   '다',
#   '그냥',
#   '최고',
#   '이',
#   '야',
#   '그러',
#   'ㄴ',
#   '줄',
#   '알',
#   '아'],
#  ['그랜드', '부다페스트', '호텔', '과', '시리즈', '같', '네', '캐스팅', '이', '아깝', '어'],
#  ['빨리감기해서', '봤음투자비', '는', '많', '이', '들', '었을', '것', '같은데영화사', '망했넿'],
#  ['도대체',
#   '뭐',
#   '가',
#   '재밌다는건지',
#   '모르',
#   '겠네',
#   '요',
#   '무슨',
#   '아이언맨',
#   '시리즈',
#   '의',
#   '개그',
#   '도',
#   '뛰어넘',
#   '는다',
#   '하',
#   'ㄴ데',
#   '어디',
#   '서',
#   '웃',
#   '어야',
#   '하',
#   'ㄹ지',
#   '도',
#   '모르',
#   '겠고',
#   '내용',
#   '도',
#   '뭔지',
#   '뜬금없',
#   '는',
#   '히어로놀이',
#   '는',
#   '또',
#   '뭔지',
#   '왜이렇게',
#   '평점',
#   '이',
#   '높',
#   '은',
#   '지',
#   '모르',
#   '겠습니다'],
#  ['왜',
#   '극',
#   '을',
#   '끌',
#   '어',
#   '가',
#   '는',
#   '중심',
#   '있',
#   '는',
#   '캐릭터',
#   '가',
#   '있',
#   '어야',
#   '하',
#   '는지',
#   '알',
#   '게',
#   '된영화',
#   '살인마',
#   '와',
#   '대적',
#   '하',
#   '어',
#   '는',
#   '그리고',
#   '사건',
#   '을',
#   '해결',
#   '하',
#   '는',
#   '인물',
#   '이',
#   '없',
#   '고',
#   '그리고',
#   '왜',
#   '마지막',
#   '에',
#   '다',
#   '탈출',
#   '하',
#   '어',
#   '놓',
#   '고',
#   '나',
#   '서',
#   '잡히',
#   '고',
#   '죽',
#   '이',
#   'ㅁ',
#   '을',
#   '당하',
#   '는지',
#   '이해',
#   '하',
#   'ㄹ',
#   '수',
#   '가',
#   '없',
#   '다',
#   '대체',
#   '조달환',
#   '정유미',
#   '는',
#   '왜',
#   '나',
#   '아',
#   '오',
#   'ㅁ'],
#  ['지',
#   'ㄴ',
#   '짜',
#   '아',
#   '리얼',
#   '개',
#   '쓰레기',
#   '영화',
#   '다',
#   '보',
#   '고',
#   '나',
#   '면',
#   '정말',
#   '찝찝해지',
#   '는',
#   '영화',
#   '절대보지마'],
#  ['비록',
#   '로봇',
#   '이',
#   '지만',
#   '점차',
#   '인간',
#   '의',
#   '감정',
#   '을',
#   '가',
#   '아',
#   '지',
#   '고',
#   '자신',
#   '에',
#   '대',
#   '어',
#   '하',
#   '어',
#   '고민',
#   '하',
#   '면서',
#   '결국',
#   '인간',
#   '이',
#   '되',
#   '어',
#   '죽',
#   '는',
#   '앤드',
#   '류',
#   '의',
#   '모습내',
#   '가',
#   '보',
#   '아ㄴ',
#   '영화',
#   '중',
#   '에서도',
#   '최고',
#   '의',
#   '감동',
#   '을',
#   '선사',
#   '하',
#   'ㄴ',
#   '영화'],
#  ['영구와땡칠이시리즈', '는', '레전드영화', '이', '다'],
#  ['초딩',
#   '때',
#   '친척형',
#   '이',
#   '비디오',
#   '로',
#   '빌리',
#   '어',
#   '오',
#   '아',
#   '보',
#   '아ㄴ',
#   '기억',
#   '이',
#   '난다너무',
#   '재미',
#   '없',
#   '었다',
#   '근데',
#   '나중',
#   '에',
#   '우연히',
#   '다시보',
#   '이',
#   '니',
#   '재밌더',
#   '이',
#   '라',
#   '그',
#   '때',
#   'ㄴ',
#   '왜',
#   '그렇',
#   '게',
#   '재미',
#   '가',
#   '없',
#   '었을까',
#   '98년',
#   '이',
#   '면',
#   '나',
#   '가',
#   '초등학교',
#   '2학년',
#   '때니까사촌형',
#   '이',
#   '당시',
#   '나름',
#   '최신',
#   '비디오',
#   '를',
#   '빌려온거',
#   '같',
#   '다'],
#  ['지루',
#   '하',
#   'ㄹ',
#   '만큼',
#   '고요',
#   '하고',
#   '서글프',
#   'ㄴ',
#   '시선속',
#   '에',
#   '머물',
#   'ㄴ',
#   '깊',
#   '은',
#   '성찰',
#   '과',
#   '사색'],
#  ['영화', '진짜', '보', '고', '펑펑울었습니다', '너무슬픈거같아요', 'ㅜㅜㅜ'],
#  ['누구', '가', '더', '혀짧은', '가', '내기', '하', '면', '박빙', '이', 'ㄹ', '것', '같', '다'],
#  ['애',
#   '둘',
#   '딸리',
#   'ㄴ',
#   '심은하',
#   '의',
#   '그',
#   '눈부시',
#   'ㄴ',
#   '미모',
#   '아름답',
#   '은',
#   '영상',
#   '메',
#   '이',
#   'ㄴ',
#   '주제가'],
#  ['3기',
#   '나',
#   '아',
#   '오',
#   '겠죠',
#   '아직',
#   '안풀린',
#   '이야기',
#   '들',
#   '이',
#   '많',
#   '은',
#   '데',
#   '극장판',
#   '은',
#   '정말',
#   '시간가는줄',
#   '도',
#   '모르',
#   '고',
#   '보',
#   '아네',
#   '요',
#   '역시',
#   '싸패'],
#  ['개노잼', '뭔가', '스토리', '도', '부족', '하고', '다이상함', '진짜'],
#  ['답', '없', '네', '뭐하', '는', '것', '이', 'ㄴ지'],
#  ['절망',
#   '과',
#   '슬프',
#   'ㅁ',
#   '속',
#   '에서도',
#   '자신',
#   '을',
#   '챙겨야만하',
#   '는',
#   '삶',
#   '의',
#   '잔인함',
#   '을',
#   '거부한',
#   '비참함',
#   '에',
#   '대하여'],
#  ['페이스', '허거', '같음ㅋㅋㅋㅋㅋ'],
#  ['시간', '이', '흐르', '어도', '퇴색', '되', '지', '않', '는', '맛', '이', '있', '는', '영화'],
#  ['진짜', '어마어마', '하', 'ㄴ', '여운', '을', '주', '는', '멜로', '영화에욯'],
#  ['소피마르소',
#   '와의',
#   '말',
#   '같',
#   '지',
#   '도',
#   '않',
#   '은',
#   '불륜',
#   '이',
#   '내용',
#   '다',
#   '망치',
#   'ㅁ',
#   '물론',
#   '실제',
#   '역사',
#   '에는',
#   '그러',
#   'ㄴ',
#   '똥',
#   '같',
#   '은',
#   '이야기',
#   '는',
#   '전혀',
#   '없었음주인공',
#   '죽',
#   '을',
#   '때',
#   '공주',
#   '는',
#   '10살이었음한마디만약',
#   '미국인',
#   '과',
#   '맞서',
#   '어',
#   '싸우',
#   '는',
#   '아메리칸',
#   '원주민',
#   '의',
#   '자유',
#   '투쟁기',
#   '이',
#   '었으면',
#   '절대',
#   '아카데미상',
#   '못',
#   '받',
#   '아ㅁ'],
#  ['훈훈', '하고', '따뜻한', '부정', '을', '느낄수잇엇음'],
#  ['잼'],
#  ['전', '정말', '재미있', '게', '보', '아ㅂ니다'],
#  ['어딘가',
#   '에서',
#   '일어나',
#   '고',
#   '일',
#   '이',
#   'ㄹ',
#   '것',
#   '같',
#   '은',
#   '느끼',
#   'ㅁ',
#   '이',
#   '강하다우베볼',
#   '이',
#   '이런',
#   '영화',
#   '를',
#   '만들',
#   '는',
#   '이유',
#   '는',
#   '누군가',
#   '실제로',
#   '따르',
#   '아',
#   '하',
#   '었으면',
#   '하',
#   '고',
#   '바라',
#   '는',
#   '것',
#   '같',
#   '은',
#   '데',
#   '정장',
#   '월',
#   '가',
#   '있',
#   '는',
#   '애',
#   '들',
#   '이',
#   '보',
#   '면',
#   '웃',
#   '겠지'],
#  ['림프비즈킷',
#   '의',
#   'OST',
#   '만',
#   '10점',
#   '개봉',
#   '당시',
#   '극장',
#   '에서',
#   '보',
#   '아ㄴ데',
#   '영화내',
#   '내',
#   '오우삼',
#   '쥑이',
#   '고',
#   '싶었던ㅋㅋ'],
#  ['견자단', '대박엽문', '시리즈', '는', '계속', '되', 'ㄴ다'],
#  ['정말',
#   '오월',
#   '의',
#   '멜로',
#   '는',
#   '정말',
#   '로',
#   '보',
#   '고',
#   '보',
#   '고',
#   '뜨',
#   '어',
#   '보',
#   '아',
#   '계속',
#   '보',
#   '고',
#   '싶',
#   '은',
#   '영화순위',
#   '1순위다하늦',
#   '은',
#   '밤',
#   '이',
#   '라',
#   '그러',
#   'ㄴ지',
#   '야릇',
#   '하',
#   'ㄴ',
#   '느끼',
#   'ㅁ',
#   '이',
#   '들',
#   '었다'],
#  ['흥미', '롭', '게', '보', '아아', '요', '여배우들', '이쁘', '네', '요', '반하', '었음'],
#  ['스토리',
#   '액션',
#   '그래픽',
#   '머',
#   '하나',
#   '건질',
#   '게',
#   '없',
#   '는',
#   '망작',
#   '그냥',
#   '게임',
#   '으로나',
#   '즐기',
#   '시어'],
#  ['그냥', '레전드다', '레전드'],
#  ['평론가',
#   '명치',
#   '를',
#   '겁',
#   '나',
#   '때',
#   '이',
#   '리',
#   '고',
#   '싶',
#   '다',
#   '정말',
#   '이',
#   '영화',
#   '재미',
#   '없',
#   '을',
#   '것',
#   '이',
#   '라',
#   '생각',
#   '하',
#   '었는데',
#   '재미',
#   '도',
#   '있',
#   '고',
#   '내',
#   '인생',
#   '에',
#   '도움',
#   '이',
#   '가장큰',
#   '영화',
#   '이',
#   'ㅂ니다',
#   '본인',
#   '이',
#   '깨달고',
#   '싶',
#   '으면',
#   '꼭',
#   '보',
#   '세',
#   '요',
#   '인생',
#   '을',
#   '바꾸',
#   '어',
#   '줄',
#   'ㄹ',
#   '것',
#   '이',
#   'ㅂ니다'],
#  ['키아누', '리브스', '최고', '의', '액션', '영화'],
#  ['소재',
#   '가',
#   '아름답',
#   '은',
#   '영화',
#   '다소',
#   '아쉽',
#   '은',
#   '부분들',
#   '이',
#   '있',
#   '는',
#   '이유',
#   '는',
#   '이',
#   '영화',
#   '는',
#   '영화',
#   '스럽',
#   '은',
#   '극',
#   '적',
#   '로맨스보',
#   '이',
#   '단',
#   '좀',
#   '더',
#   '사',
#   '시ㄹ',
#   '적',
#   '으로',
#   '하',
#   'ㄴ',
#   '남자',
#   '의',
#   '마음',
#   '과',
#   '시선',
#   '을',
#   '말',
#   '하고',
#   '싶',
#   '었기',
#   '때문',
#   '아니',
#   'ㄹ까'],
#  ['영화평론가',
#   '는',
#   '아니',
#   '지만',
#   '좋',
#   '아다',
#   '한번보고마',
#   '는',
#   '영화',
#   '가',
#   '아니',
#   'ㄴ',
#   '울림이있는영화'],
#  ['역시', '효느', '역시', '재밌닼ㅋㅋ', '재탕중'],
#  ['4대강'],
#  ['간첩색휘들', '애쓰', 'ㄴ다', '밥', '은', '먹', '고', '다니', '냐'],
#  ['좀', '검증', '되', 'ㄴ', '애들좀', '출현시켜라이탈리아', '특집', '장난', '하', '냐'],
#  ['아', '정말짜증나', '이', '네', '절때보지말껄욕나옴'],
#  ['슬프', '다', 'ㅠㅠ'],
#  ['최악',
#   '의',
#   '환경속',
#   '에서',
#   '이런',
#   '만화',
#   '이',
#   '라',
#   '도',
#   '만든사람들에',
#   '이',
#   '게',
#   '경의',
#   '를',
#   '보내',
#   'ㄴ다'],
#  ['What', 'is', 'this', 'movie', 'for'],
#  ['여운',
#   '이',
#   '엄청길',
#   '게',
#   '남는영화',
#   '이이',
#   '경',
#   '을',
#   '사랑',
#   '하',
#   '게',
#   '하',
#   '는',
#   '영화'],
#  ['이딴게', '한국', '영화라', '이', '니'],
#  ['짜', '아', '가', '아', '인가', '이게뭐여뭔'],
#  ['굿', '10자', '이상', '가나다', '이', '라'],
#  ['짱이닿',
#   '혼자자식키우며살아온엄마',
#   '그의아들',
#   '힘들게살아오',
#   '이',
#   '면서',
#   '서로예민해지고날카로워질때도잇엇지',
#   '만',
#   '결국',
#   '가족ㅎ',
#   '아빠',
#   '라는',
#   '사람',
#   '도',
#   '생각보다최악이아니고여자',
#   '는',
#   '확실히',
#   '요구하면도와준다',
#   '는',
#   '그말',
#   '이',
#   '왠지짠하게와닿는닿',
#   '나혼자괜히끙끙거리지말자ㅡ이런단순한생각이든다'],
#  ['CG',
#   '도',
#   '별',
#   '로이',
#   '고',
#   '전개도',
#   '별',
#   '로이',
#   '고',
#   '연기',
#   '도',
#   '별',
#   '로이',
#   '고',
#   '한마디',
#   '로',
#   '재미',
#   '없',
#   '다'],
#  ['번지수', '잃', '고', '갈팡질팡'],
#  ['Yesterday', 'when', 'i', 'was', 'young'],
#  ['너무', '사랑', '스럽', '고', '감동적', '이', 'ㄴ', '영화', '정말', '좋앗어요'],
#  ['최고의영화'],
#  ['13년',
#   '전',
#   '영활',
#   '다시보니',
#   '공효진',
#   '코평수줄',
#   '이',
#   '고',
#   '콧대높였네완전',
#   '못생기',
#   '었어',
#   'ㅎㅎ호',
#   '권상우',
#   '는',
#   '화산고',
#   '때',
#   '왼쪽',
#   '팔',
#   '자',
#   '심하',
#   '더니',
#   '지금',
#   '사라지',
#   '고',
#   '더',
#   '잘생기',
#   '어',
#   '지',
#   '었고',
#   '장혁',
#   '은',
#   '멋지',
#   '게',
#   '늙',
#   '었네',
#   'ㅋㅋㅋ다시보',
#   '이',
#   '니',
#   '웃기',
#   '어'],
#  ['말랑말', '랑'],
#  ['공부', '열심히', '하', 'ㅂ시다', '공부', '안하', '이', '면', '저런', 'OO', '인생', '살', 'ㅂ니다'],
#  ['그냥', '최고', '이', '다'],
#  ['전쟁이후',
#   '의',
#   '아프',
#   'ㅁ',
#   '을',
#   '잘',
#   '그린영화마지막',
#   '장면',
#   '이',
#   '압권유대',
#   '이',
#   'ㄴ',
#   '줄',
#   '알',
#   '아',
#   '더럽',
#   '게',
#   '여기',
#   '나',
#   '도움',
#   '이',
#   '필요하니동행했던',
#   '토마스에',
#   '이',
#   '게',
#   '더러운유태인이라',
#   '이',
#   '고',
#   '말한장면',
#   '그러나',
#   '유대인인척한',
#   '사',
#   '시ㄹ',
#   '유대인가족사진',
#   '을',
#   '보',
#   '면서',
#   '미묘한',
#   '감정들',
#   '을',
#   '사슴인형',
#   '을',
#   '밟아까',
#   '이',
#   '며',
#   '대변한다므찐영화'],
#  ['오랜만', '에', '동화다운', '동화', '를', '보', 'ㄴ', '기분', '이', '다'],
#  ['감사', '하', 'ㅂ니다', '정말', '로', '감사', '하', 'ㅂ니다'],
#  ['걍', '둘다', '변태'],
#  ['샤넬', '의', '인생', '과', '성공', '이', '아니', '라', '샤넬', '과', '그', '의', '남자들'],
#  ['영화', '가', '내용', '이', '없', '다'],
#  ['십수년',
#   '의',
#   '세월',
#   '을',
#   '찰나',
#   '의',
#   '순간',
#   '처럼',
#   '찰나',
#   '의',
#   '순간',
#   '을',
#   '영원',
#   '하',
#   'ㄴ',
#   '기억',
#   '으로',
#   '남',
#   '기',
#   '는',
#   '시간',
#   '의',
#   '상대성',
#   '이론',
#   '에',
#   '관하',
#   '어'],
#  ['니노', '의', '이중인격연기', '두근거리', '네요'],
#  ['보', '다가', '울컥핫', '영화재미', '도', '있고먼', '가', '감동적임'],
#  ['열정만', '으로', '돌진', '하고', '싶', '게', '만들', '는', '영화'],
#  ['연기력', '에서', '유혹', '하', '지', '못하', 'ㄴ다'],
#  ['난감',
#   '하',
#   '어다',
#   '재미',
#   '도',
#   '없',
#   '고',
#   '세상',
#   '을',
#   '깜짝',
#   '놀라',
#   '게',
#   '하',
#   '는',
#   '센세이션',
#   '도',
#   '없',
#   '다'],
#  ['아무리',
#   '노력',
#   '하',
#   '었어도',
#   '차이나타운',
#   '을',
#   '대',
#   '어',
#   '놓',
#   '고',
#   '베끼',
#   'ㄴ',
#   '것',
#   '은',
#   '용서',
#   '가',
#   '알',
#   'ㄴ',
#   '됨'],
#  ['신화', '화이팅', '에릭', '화이팅', '모두', '힘내', '어요'],
#  ['엔딩', '이', '널', 'ㅁ', '슬프', '어요'],
#  ['영화관',
#   '에',
#   '가',
#   '서',
#   '보',
#   '면',
#   '더',
#   '좋았을걸어린시절',
#   '로',
#   '돌',
#   '아',
#   '가',
#   'ㄴ',
#   '느낌이들어',
#   '만감',
#   '이'],
#  ['정말',
#   '최고',
#   '이',
#   '었어',
#   '요',
#   'ㅠㅠ',
#   '이민정씨',
#   '와',
#   '신하균씨',
# ...
#   '도',
#   '개떡',
#   '이고'],
#  ['최고', '의', '농촌드라마'],
#  ['독립영화',
#   '실력자들',
#   '의',
#   '스타',
#   '리그',
#   '옴니버스',
#   '라는',
#   '피로감',
#   '이',
#   '극복',
#   '되',
#   '는',
#   '수준',
#   '이',
#   '다',
#   '얼음강',
#   '은',
#   '단독',
#   '장편',
#   '으로',
#   '만들',
#   '었어도',
#   '좋',
#   '아ㄹ',
#   '듯',
#   '주인공',
#   '이',
#   '혹여',
#   '평소',
#   '이',
#   '라면',
#   '1',
#   '도',
#   '공감',
#   '안되',
#   '는',
#   '여호와',
#   '의',
#   '증인',
#   '이',
#   '라',
#   '도',
#   '납득',
#   '이',
#   '되',
#   'ㄹ',
#   '정도',
#   '로',
#   '감정',
#   '을',
#   '설득',
#   '하',
#   '는',
#   '솜씨',
#   '가',
#   '탁월',
#   '하',
#   '다'],
#  ['좀비좀비',
#   '그러',
#   'ㄴ데',
#   '좀비아닙니다',
#   '우주',
#   '의',
#   '아름다움',
#   '에',
#   '미치',
#   '어',
#   '버리',
#   'ㄴ',
#   '인간',
#   '이',
#   'ㄹ',
#   '뿐',
#   '충분히',
#   '가능',
#   '하',
#   'ㄴ',
#   '일',
#   '이',
#   '죠'],
#  ['개재미', '없', '음', '막장스토리', '어거지', 'ㅋㅋ'],
#  ['뭐하', '어', '나', '아', '흠잡', '을', '것', '이', '없', '다', '최고'],
#  ['OST', '가', '좋', '은', '영화'],
#  ['탁재훈나오믄재밌는데와이라지스토리중반부터너무쳐짐약해약해약해지겨워뒈지는줄알'],
#  ['서스펜스', '도', '없', '고', '스릴', '도', '없', '다'],
#  ['우리나라', '정서', '하고', '안맞다'],
#  ['어디선', '가', '많', '이', '보', 'ㄴ', '흔하', 'ㄴ', '스토리'],
#  ['최고', '의', '드라마'],
#  ['우리', '모두', '는', '누군가', '에게', '섬머', '이', '었다'],
#  ['힘알', '이', '하', '나', '없', '는', '주인공들맥', '이', '다', '빠지', 'ㄴ다'],
#  ['너무너무귀여운영화'],
#  ['전형적',
#   '이',
#   'ㄴ',
#   '일본식',
#   '엽기',
#   '괴짜',
#   '코메디',
#   '그',
#   '특이함',
#   '에',
#   '끌리는건',
#   '왜',
#   '이',
#   '지'],
#  ['오',
#   '아',
#   '이걸',
#   '5점',
#   '이상',
#   '주',
#   'ㄴ',
#   '사람',
#   '들',
#   '은',
#   '뭐',
#   '이',
#   '지',
#   '나루토',
#   '극장판',
#   '중',
#   '에',
#   '가장',
#   '쓰래',
#   '이',
#   '기'],
#  ['정당한',
#   '노력',
#   '이란',
#   '보상',
#   '받',
#   '게',
#   '마련이다나름',
#   '일정',
#   '성취',
#   '가',
#   '있',
#   '고',
#   '좋',
#   '은',
#   '결실',
#   '을',
#   '거두',
#   'ㄴ',
#   '작품'],
#  ['아씨', '울', '었다'],
#  ['기적', '은', '이미', '일', '어', '나', '아다'],
#  ['아이들', '과', '함께', '보', '기', '좋', '아지만', '그냥', '그래요'],
#  ['전율', '을', '느끼', '었다'],
#  ['여기저기',
#   '지저분한내용',
#   '에',
#   '이기적',
#   '이',
#   'ㄴ',
#   '사람',
#   '들',
#   '의',
#   '역겹',
#   '은',
#   '연애사마지막',
#   '으로',
#   '가',
#   'ㄹ수록',
#   '시청률',
#   '안나오',
#   '이',
#   '니까',
#   '막',
#   '갈겨쓴내용'],
#  ['별로완전별로마지막빼', '이', '고', '널', 'ㅁ', '유치하고재미없', '고'],
#  ['세월',
#   '이',
#   '지나',
#   '아',
#   '다시',
#   '보',
#   '니',
#   '뭔가',
#   '먹먹함',
#   '이',
#   '다르',
#   '더군',
#   '요',
#   '공감',
#   '하',
#   '는',
#   '사람',
#   '이',
#   '라면',
#   '가슴속',
#   '에',
#   '명작',
#   '으로',
#   '남',
#   '을',
#   '듯'],
#  ['아이들', '이', '보', '기', '엔', '좋', '을지', '도'],
#  ['보', '니까', '선정성', '이', '좀', '15세', '같', '음', '그래도', '액션', '은', '좋', '음'],
#  ['카타르시스', '를', '느끼', '기', '에', '충분한값진영화', '이', '었다'],
#  ['여주',
#   '린제',
#   '이',
#   '로한',
#   '닮',
#   '아다',
#   '전체적',
#   '이',
#   'ㄴ',
#   '분위기',
#   '나',
#   '배경',
#   '은',
#   '좋',
#   '아지만',
#   '내용',
#   '은',
#   '지루',
#   '하',
#   '었다'],
#  ['당신', '이', '솔로', '가', '아니', '면', '이', '영화', '를', '보지마세요'],
#  ['남',
#   '이',
#   '차안',
#   '에서',
#   '전화통화',
#   '하는걸',
#   '90분',
#   '가까이',
#   '구경',
#   '하고',
#   '있',
#   '으라',
#   '고',
#   '폰부스',
#   '는',
#   '명작',
#   '이',
#   '라',
#   '생각',
#   '하',
#   '지',
#   '말',
#   'ㄴ',
#   '이',
#   '영화',
#   '는',
#   '진짜',
#   '장난',
#   '하',
#   '나'],
#  ['전형적', '이', 'ㄴ', '저질영화'],
#  ['답', '을', '알리', '어', '고', '하지마', '이', '라'],
#  ['재미잇음매우'],
#  ['진짜', '잘', '만들', 'ㄴ', '수작'],
#  ['제발', '2좀', '찍', '어', '주', '세', '요', '현기증', '나', 'ㄴ단', '말', '이', '에요'],
#  ['너무나',
#   '도',
#   '따뜻한',
#   '마음',
#   '이',
#   '따뜻해지',
#   '는',
#   '한번쯤',
#   '자신',
#   '을',
#   '되돌',
#   '아',
#   '보',
#   '게',
#   '만들',
#   '는',
#   '영화'],
#  ['뭔가',
#   '조금씩',
#   '부족한',
#   '영화',
#   '놀래킬려',
#   '이',
#   '면',
#   '확',
#   '놀래키던지',
#   '어정쩡',
#   '하',
#   'ㄴ',
#   '_'],
#  ['이거',
#   '참',
#   '소재',
#   '는',
#   '참',
#   '좋',
#   '은',
#   '데',
#   '내용전개',
#   '가',
#   '개판사람수',
#   '도',
#   '많',
#   '고',
#   '총',
#   '도',
#   '있',
#   '는데',
#   '그걸',
#   '지들끼리',
#   '서로',
#   '다',
#   '흩',
#   '어',
#   '지',
#   '어서',
#   '일방적',
#   '으로',
#   '밀리네거기다',
#   '식인종',
#   '이라면서',
#   '표현',
#   '을',
#   '좀비',
#   '로',
#   '하',
#   '어',
#   '놓',
#   '으면',
#   '어쩌잔거야식인',
#   '으로',
#   '인하',
#   '어',
#   '인성',
#   '이',
#   '말살',
#   '되',
#   '고',
#   '짐승화',
#   '되',
#   '었다는',
#   '표현',
#   '이',
#   '라',
#   '도',
#   '있',
#   '던가'],
#  ['포스터',
#   '만',
#   '그럴싸하',
#   '어다',
#   '13구역',
#   '이',
#   '라는',
#   '이름',
#   '만',
#   '가',
#   '아',
#   '지',
#   '어다',
#   '쓰',
#   'ㄴ',
#   '영화',
#   '완전',
#   '졸작',
#   '이',
#   '다',
#   '액션',
#   '신',
#   '도',
#   '개허술하',
#   '이',
#   '고',
#   '스토리',
#   '도',
#   '이상',
#   '하',
#   '다'],
#  ['대체', '왜', '재미없다는거지난', '존나재밌던데'],
#  ['늑대들',
#   '의',
#   '여정',
#   '이',
#   '너무',
#   '낭만적',
#   '이',
#   '었던',
#   '애',
#   '이',
#   '니',
#   '스토리',
#   '도',
#   '좋',
#   '지',
#   '말',
#   'ㄴ',
#   '음악',
#   '은',
#   '일본',
#   '애니중',
#   '에',
#   '탑',
#   '으로',
#   '뛰어나',
#   '다'],
#  ['미국', '흑', '이', 'ㄴ', '민권운동사', '를', '완벽', '하', '게', '요약', '하', '었다'],
#  ['그', '가', '뛰', '어', '내리', '지', '않았다', '이', '면', '어떻', '게', '되', '이', '었을까'],
#  ['8점',
#   '대',
#   '는',
#   '나',
#   '아',
#   '오',
#   '아',
#   '그냥',
#   '단순',
#   '하',
#   'ㄴ',
#   '액션공포물',
#   '이',
#   '아니',
#   'ㄴ데',
#   '도',
#   '긴장감',
#   '공포감',
#   '연출',
#   '쩔고',
#   '음악',
#   '도',
#   '좋',
#   '고',
#   '몇년',
#   '이',
#   '지나',
#   '아',
#   '기억나',
#   '는',
#   '인상적',
#   '이',
#   'ㄴ',
#   '좀비물',
#   '이',
#   'ㄴ데',
#   '평점',
#   '너무',
#   '짜',
#   '아',
#   '10줌'],
#  ['아역', '연기', '는', '좋', '아나', '내용', '은', '쓰레기'],
#  ['진짜재미',
#   '없',
#   '다',
#   '극장',
#   '에서',
#   '볼거없어서',
#   '걍',
#   '스릴러라길래봤는뎈ㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋ웃음밖에안나온다',
#   '혹시나해서라',
#   '도',
#   '절대보지마라진짜제발'],
#  ['평점', '은', '믿지마셈', '재밌음'],
#  ['이거', '좋', '다는', '놈', '들', '은', '뭐하', '는', '것들이야', 'ㅡㅡ'],
#  ['이', '이', '게', '21c영화냐', '90년도영화냐', '쓰래기들', '아'],
#  ['ufo', '를', '믿', '으리어는', '자', '들'],
#  ['너무',
#   '구식',
#   '으로',
#   '웃길려',
#   '이',
#   '고',
#   '하',
#   'ㅁ',
#   '보',
#   '는',
#   '내',
#   '어',
#   '내',
#   '어',
#   '지겹',
#   '음'],
#  ['이런거', '좋', '아', '하', '는', '사람들', '정신', '세계', '가', '궁금', '하', '다'],
#  ['연예계',
#   '의',
#   '현실',
#   '을',
#   '알리고',
#   '이',
#   '자',
#   '하',
#   '는',
#   '마음',
#   '은',
#   '알',
#   '겠지만',
#   '영화',
#   '의',
#   '재미',
#   '는',
#   '없',
#   '었다',
#   '지루',
#   '하',
#   '어',
#   '죽',
#   '을',
#   '뻔',
#   '하',
#   '었음'],
#  ['아주', '재미있', '고', '책으로봐', '도', '정말재미', '있', '다'],
#  ['끝내', '어', '주', '게', '재밌다'],
#  ['유투브동영상',
#   '을',
#   '돌',
#   'ㄴ',
#   '내',
#   '이',
#   '고',
#   '보',
#   '는게',
#   '낫',
#   '다는',
#   '생각',
#   '이',
#   '들',
#   '게',
#   '하',
#   'ㄴ',
#   '영화'],
#  ['아쉽',
#   '은',
#   '점',
#   '도',
#   '있',
#   '지',
#   '말',
#   'ㄴ',
#   '스토리',
#   '에',
#   '맞',
#   '는',
#   '분위기',
#   '나',
#   '배경',
#   '지하철기관사',
#   '의',
#   '삶',
#   '등',
#   '을',
#   '잘',
#   '묘사'],
#  ['스타워즈',
#   '1편',
#   '과',
#   '맞아떨어지도록',
#   '잘',
#   '만든영화',
#   '최고',
#   '의',
#   '에피소드',
#   '다스베이더',
#   '의',
#   '탄생',
#   '과',
#   '루크레이어',
#   '의',
#   '운명',
#   '을',
#   '알',
#   'ㄹ',
#   '수',
#   '있',
#   '는',
#   '레전드'],
#  ['소희', '가', '귀엽', '다', '귀엽', '다', '졸귀'],
#  ['소문나', 'ㄴ', '잔치호화', '캐스팅', '에', '먹', '을', '거', '은', '없', '다'],
#  ['주성치', '영화', '최고', '의', '졸작'],
#  ['구우우웃'],
#  ['딱히', '흠잡', '을', '것', '도', '두근거리', 'ㄹ', '것', '도', '없', '는', '교과서적', '플레이'],
#  ['영화',
#   '의',
#   '중심',
#   '은',
#   '역시',
#   '스토리',
#   '이',
#   'ㄴ',
#   '것',
#   '을',
#   '반전',
#   '의',
#   '반전',
#   '너무',
#   '재미있',
#   '다'],
#  ['83', '이', '아니', '라', '93', '이', '아니', 'ㄴ가'],
#  ['참',
#   '재미있',
#   '었다',
#   '연기',
#   '를',
#   '발',
#   '로',
#   '하',
#   '는',
#   '삼류배우들',
#   '얼굴보',
#   '이',
#   '면서',
#   'ㅋㅋㅋ'],
#  ['재밌군'],
#  ['이것', '도', '재밌는뎈ㅋ'],
#  ['1점',
#   '도',
#   '아깝',
#   '다',
#   '평쓰',
#   '는',
#   '것',
#   '도',
#   '귀찮',
#   '다',
#   '보',
#   '는',
#   '내',
#   '어',
#   '내',
#   '어',
#   '오글거려서',
#   '손발사라지',
#   '는',
#   '주',
#   'ㄹ',
#   '알',
#   '아다'],
#  ['기대',
#   '안',
#   '하고',
#   '보',
#   '아ㄴ데',
#   '영화',
#   '보',
#   '는',
#   '내',
#   '어',
#   '내',
#   '어',
#   '몰입',
#   '하',
#   '어서',
#   '재미있',
#   '게',
#   '보',
#   '아아'],
#  ['유쾌함',
#   '과',
#   '스릴러적',
#   '이',
#   'ㄴ',
#   '요소',
#   '가',
#   '잘',
#   '어울리',
#   '어',
#   '지',
#   'ㄴ',
#   '명작',
#   '후속작',
#   '보다',
#   '훨씬',
#   '매력',
#   '있',
#   '음',
#   '두',
#   '이',
#   '고',
#   '두',
#   '이',
#   '고',
#   '간직',
#   '하',
#   '어',
#   '두',
#   '면서',
#   '꺼내',
#   '어',
#   '보',
#   '고',
#   '싶',
#   '은',
#   '영화'],
#  ['좋네괜찮', '고'],
#  ['명작',
#   '너무',
#   '좋',
#   '아ㄴ',
#   '드라마',
#   '스토리',
#   '캐스팅',
#   '연기',
#   '음악',
#   '연출',
#   '모두',
#   '완벽',
#   '하',
#   '었던'],
#  ['괜찮은영화영화도괜찮았지만', '나영언니완전머싯고예뻤음ㅠㅠ'],
#  ['일단',
#   '재미있',
#   '다',
#   '고래',
#   '몇마리',
#   '로',
#   '국가적',
#   '으로',
#   '호들갑떠는',
#   '게',
#   '오버',
#   '스럽',
#   '겠지만',
#   '그러',
#   'ㄴ',
#   '모습',
#   '이',
#   '우리',
#   '는',
#   '모두',
#   '가',
#   '돕',
#   '어',
#   '가',
#   '며',
#   '살',
#   '아',
#   '하',
#   '는',
#   '지구',
#   '의',
#   '생명',
#   '이란',
#   '메세지',
#   '는',
#   '차',
#   'ㅁ',
#   '으로',
#   '감동적',
#   '이',
#   '다'],
#  ['지금',
#   '첨봤는데',
#   '1회',
#   '만',
#   '보',
#   '아',
#   '보',
#   'ㄹ까',
#   '하고',
#   '보',
#   '아다가',
#   '주말',
#   '밤새완주',
#   '하',
#   '었다',
#   '여운',
#   '이',
#   '많',
#   '이',
#   '남',
#   '는',
#   '드라마'],
#  ['애니메이션',
#   '뮬란',
#   '이',
#   '아쉽',
#   '다',
#   '전쟁씬',
#   '도',
#   '그렇',
#   '고',
#   '연기',
#   '도',
#   '그렇',
#   '고',
#   '이야기',
#   '도',
#   '그렇고그저',
#   '그래'],
#  ['기대않', '하', '고', '봣는데', '진짜', '내용', '도', '좋', '고', '재미', '도', '있', '네요'],
#  ['좋', '아다'],
#  ['슬프', 'ㄴ', '맑음', '파문', '에', '주목', '하', '어라'],
#  ['김윤진', '좋아하니깐'],
#  ['재밌따'],
#  ['무리수', '가', '되', '어', '버리', 'ㄴ', '코미디', '기획상품'],
#  ['나홀로집에와더불어', '나의최고의영화'],
#  ['나', '는', '떠오르', '아다', '그옛날', '국산애', '이', '니', '아마겟돈', '의', '악몽', '이'],
#  ['완전',
#   '역겹',
#   '은',
#   '쓰레기',
#   '영화',
#   '이',
#   '다',
#   '기술적',
#   '수준',
#   '을',
#   '떠나',
#   '아',
#   '각본',
#   '이',
#   '무개념'],
#  ['sunday',
#   'booldy',
#   'sunday',
#   '고결',
#   '하',
#   'ㄴ',
#   '신사들',
#   '께서',
#   '무슨',
#   '짓',
#   '을',
#   '하셧을까'],
#  ['크', '어', '개안음ㅎㅎㅎㅎ'],
#  ['보는내내', '너무너무', '재미있', '었음'],
#  ['김소현', '팬됬습니다너무', '재밌음'],
#  ['삐에로', '와', '흑인남자와싸웠을때', '재미있', '었다', 'ㅋㅋㅋ아웃겨'],
#  ['유럽영화',
#   '가',
#   '이번정부',
#   '에',
#   '많',
#   '이',
#   '들',
#   '어',
#   '오',
#   '아',
#   '즐겁긴하다만',
#   '그',
#   '내용들',
#   '이',
#   '왜',
#   '이리',
#   '진부한걸까유럽영화',
#   '를',
#   '욕',
#   '되',
#   '게',
#   '하',
#   '고',
#   '있',
#   '단',
#   '소리',
#   '이',
#   '다'],
#  ['왠만한',
#   '허접영화',
#   '도',
#   '재미있',
#   '게',
#   '보',
#   'ㄴ데',
#   '이',
#   '이',
#   '건',
#   '도',
#   '를',
#   '넘',
#   '어서었다'],
#  ['어떤',
#   '누구',
#   '도',
#   '다른',
#   '이',
#   '의',
#   '삶',
#   '과',
#   '죽음',
#   '에',
#   '대',
#   '어',
#   '하',
#   '어',
#   '왈가왈부',
#   '하',
#   'ㄹ',
#   '순',
#   '없',
#   '다'],
#  ['굿굿굿', '또해라또해', '이', '라', '제발', 'ㅠㅠ'],
#  ['주님', '께서', '부르', '시어서', '저', '가', '여기', '있나', '이', '다'],
#  ['미성년자',
#   '가',
#   '돈많',
#   '은',
#   '아저씨',
#   '에게',
#   '순결',
#   '을',
#   '바치',
#   '고',
#   '데',
#   '이',
#   'ㄴ후',
#   '결국',
#   '정신차',
#   '이',
#   '리',
#   '고',
#   '공부해거',
#   '명문대가',
#   '는',
#   '진부한',
#   '결말'],
#  ['정말',
#   '재밌',
#   '게',
#   '보',
#   '아고',
#   '빈센트',
#   '도',
#   '꼬마',
#   '도',
#   '연기',
#   '너무',
#   '잘하',
#   '네',
#   '요',
#   'ㅎ'],
#  ['솔직히', '원작', '보다', '훨씬낫다', '원작', '무슨', '인간', '이', '말도못하게설정해놨어'],
#  ['말', '이', '필요', '없', '음', '아', '진심', '개재밌다ㅠㅠ'],
#  ['보', '니까', '이양반', '이', '다세포소녀', '감독', '이', '네'],
#  ['굿', '잡', '친구', '랑', '또', '보', '고', '싶', '네요'],
#  ['재미진짜', '흥하', '네', '근데', 'yang', '이새끼', '관종인', '가', 'ㅋㅋㅋ'],
#  ['야경꾼', '보다', '엉망지루함'],
#  ['예원찡', '그만울어'],
#  ['근',
#   '5년',
#   '동안',
#   '보',
#   'ㄴ',
#   '모든영화',
#   '통틀',
#   '어서',
#   '최악의영화시간',
#   '이',
#   '남아돌',
#   'ㄹ',
#   '때',
#   '보',
#   '아',
#   '시간',
#   '이',
#   '아깝',
#   '은',
#   '역대급',
#   '쓰레기영화'],
#  ['감동',
#   '이',
#   '다',
#   '참고',
#   '로',
#   '이',
#   '영화',
#   '보신분',
#   '들',
#   '마지막엔딩부분',
#   '에',
#   '자막으로나오는부분잇죠',
#   '이',
#   '이',
#   '게',
#   '영화상',
#   '에서',
#   '실화라는거지',
#   '진짜',
#   '레알',
#   '현재',
#   '실제로',
#   '실화라는말이아니에요',
#   '전지현',
#   '이',
#   '피디잔아요',
#   '다큐찍는거',
#   '그',
#   '다큐에서엔딩장면이지',
#   '진짜',
#   '실제가아니에',
#   '이',
#   '어',
#   '쨋',
#   '든'],
#  ['달기지미니어쳐',
#   '트',
#   '어',
#   '팍팍',
#   '나던데우뢔매',
#   '보',
#   '는',
#   '줄',
#   '알았다혹시',
#   '특수효과',
#   '감독',
#   '이',
#   '심형래'],
#  ['재미', '드럽게', '없닼ㅋㅋ'],
#  ['야', '세르게', '이', '작', '은', '고추', '의', '매운맛', '을', '보', '여', '주', '이', '마'],
#  ['정여립',
#   '과',
#   '정철',
#   '기축옥사',
#   '까지',
#   '스토리',
#   '탄탄',
#   '하',
#   '어서',
#   '좋',
#   '습니다',
#   '배우들',
#   '도',
#   '연기',
#   '참',
#   '잘하',
#   '고',
#   '남녀주인공들',
#   '케미',
#   '도',
#   '좋',
#   '고',
#   '챙기',
#   '어',
#   '보',
#   'ㄹ',
#   '수',
#   '밖',
#   '에',
#   '없',
#   '는',
#   '드라마ㅠㅠㅠㅠ'],
#  ['개OO영화네요내용도없고', '그냥심심해서만든영화가'],
#  ['두개',
#   '는',
#   '줄',
#   '려고',
#   '하',
#   '었는데',
#   '알',
#   'ㄹ',
#   '바',
#   '가',
#   '많',
#   '아',
#   '아후',
#   '볼거없어서',
#   '채널',
#   '돌리',
#   '어도',
#   '다시',
#   '다르',
#   'ㄴ',
#   '데',
#   '로',
#   '돌리',
#   '이',
#   '게',
#   '만들',
#   '는구나'],
#  ['왜', '0점', '은', '주', 'ㄹ', '수', '없', '나요'],
#  ['영화사', '에', '남', '을', '작품', '실험영화', '의', '완성본'],
#  ['자식', '을', '그렇', '게', '때리', '냐'],
#  ['이', '이', '게', '대체', '무슨', '내용', '이야'],
#  ['ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋ옛다',
#   '1점',
#   '이나',
#   '처먹어랔ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋ',
#   '이',
#   '게',
#   '7점',
#   '급',
#   '이',
#   '건',
#   '1점',
#   '짜리',
#   '내용',
#   '도',
#   '결말',
#   '도',
#   '살',
#   '다',
#   '살',
#   '다',
#   '뭐',
#   '이딴'],
#  ['감동적이', '이', '었고', '좋', '아ㅂ니다'],
#  ['초반',
#   '에',
#   '개재미',
#   '없',
#   '었는데',
#   '보',
#   'ㄹ수록',
#   '점점',
#   '재밌어짐',
#   '외계인',
#   '이',
#   '나',
#   '가',
#   '알',
#   '던',
#   '에일리언',
#   '에',
#   '나',
#   '아',
#   '오',
#   '던',
#   '외계인',
#   '이',
#   '아니야'],
#  ['쇼핑백', '잊히', '어', '지', '지', '않', '는다'],
#  ['의', '도는', '좋', '지만', '너무', '몰입', '이', '안되는걸', '어떡하', '어'],
#  ['유치', '하', '지만', '가볍', '게', '보', 'ㄹ', '만', '하', 'ㅁ'],
#  ['화',
#   '이',
#   '리어',
#   '하',
#   'ㄴ',
#   '색채때문',
#   '에',
#   '눈',
#   '이',
#   '아프',
#   '지',
#   '말',
#   'ㄴ',
#   '그',
#   '나름',
#   '대로',
#   '화려연예계여자욕망에대해',
#   '표현해냈던거같다',
#   '보는내내',
#   '진짜',
#   '리리코심정가진',
#   '연옌들',
#   '도',
#   '있을거같고나를한번도보지못하고알지못하는사람들이날어떻게사랑하냐그런대사',
#   '나',
#   '아',
#   '오',
#   '아ㄹ',
#   '때',
#   '소름돋더라',
#   '연예',
#   '이',
#   'ㄴ들',
#   '은',
#   '많은사랑',
#   '받',
#   '으면',
#   '서도',
#   '참',
#   '허전',
#   '하',
#   'ㄹ',
#   '듯'],
#  ['보',
#   'ㄴ지',
#   '수OO',
#   '이',
#   '지나',
#   '아',
#   '아직',
#   '도',
#   '생생하',
#   'ㅁ',
#   '고양이',
#   '귀신',
#   '의',
#   '복수',
#   '가',
#   '진짜',
#   '무섭',
#   '었지'],
#  ['영상',
#   '이',
#   '대학교',
#   '졸업작품',
#   '같',
#   '아',
#   '그렇',
#   '지',
#   '끄',
#   '어',
#   '나',
#   '아',
#   '많은걸',
#   '담',
#   '아',
#   '놓',
#   '은',
#   '영화',
#   '이',
#   'ㅁ',
#   '에는',
#   '분명',
#   '하',
#   '다'],
#  ['최강', '전차부대'],
#  ['ㅇㅇ'],
#  ['진짜',
#   '어이없',
#   '는',
#   '소재',
#   '이',
#   '라',
#   '고',
#   '생각',
#   '하',
#   '며',
#   '보',
#   'ㄴ데',
#   '개',
#   '웃기',
#   '어',
#   '남자',
#   '로서는',
#   '솔직히',
#   '조금',
#   '은',
#   '부럽',
#   '을',
#   '수',
#   '도',
#   '있',
#   '는'],
#  ['tv', '전기세가', '아깝', '었다'],
#  ['초등학교때',
#   '선생님',
#   '이',
#   '보이',
#   '어',
#   '주',
#   '시ㄴ',
#   '영화',
#   '시간',
#   '이',
#   '흐르',
#   '어서',
#   '기억나는건',
#   '에이즈',
#   '에',
#   '걸리',
#   '었던',
#   '남자아이',
#   '와',
#   '운동화',
#   '이',
#   '었고',
#   '그때',
#   '보',
#   '아ㄴ',
#   '영화',
#   '가',
#   '뭐',
#   '이',
#   '었을까',
#   '궁금',
#   '하',
#   '었었는데',
#   '그',
#   '영화',
#   '가',
#   '바로',
#   '굿바이마이프렌드였다',
#   '12년',
#   '전',
#   '이나',
#   '12년후',
#   '나',
#   '명작',
#   '은',
#   '시간',
#   '이',
#   '흐르',
#   '어도',
#   '명작',
#   '이',
#   '다'],
#  ['널', 'ㅁ', '재밌었어욧ㅎㅎㅎ'],
#  ['서', 'ㄹ', '리', '94년생', '이', 'ㄴ데', '93년', '도', '영화', '에', '어떻', '게', '나오져'],
#  ['샷',
#   '의',
#   '연결',
#   '이',
#   '아니',
#   'ㄴ',
#   '충돌',
#   '만큼이나',
#   '거룩한',
#   '제목',
#   '또한',
#   '인상적이구',
#   '이',
#   '려'],
#  ['ㅋㅋㅋ', '재미', '없', '음'],
#  ['오오',
#   '나',
#   'ㄴ',
#   '여태',
#   '까지',
#   '맷데이먼',
#   '의',
#   '최고의영화',
#   '는',
#   '보',
#   'ㄴ',
#   '얼티메이텀라이언일병구하',
#   '이',
#   '기',
#   '뿐인줄알았음ㅠ',
#   '굿윌헌팅도쩐당'],
#  ['이야기', '자체', '가', '흥미', '를', '끌', '지', '못하', '는군'],
#  ['나', 'ㄹ', '로그인하', '이', '게', '만들다니청춘이', '이', '어', '영원', '하', '어라'],
#  ['현정언니', '짱이죠', '완전', '잼잇어요', 'ㅎ'],
#  ['영상미',
#   '예쁘',
#   '고',
#   '좋',
#   '지',
#   '말',
#   'ㄴ',
#   '러닝타임',
#   '이',
#   '2시간',
#   '이',
#   '넘',
#   '는데',
#   '초반',
#   '30분',
#   '에',
#   '주',
#   'ㄹ',
#   '것',
#   '이',
#   '리',
#   '다',
#   '나',
#   '아',
#   '가',
#   '아고',
#   '엄청',
#   '지루',
#   '하',
#   'ㄴ',
#   '화보집',
#   '보',
#   '는',
#   '기분',
#   '일본영화',
#   '특유',
#   '의',
#   '그',
#   '이해',
#   '못하',
#   'ㄹ',
#   '희한',
#   '하',
#   'ㅁ',
#   '이',
#   '있',
#   '음'],
#  ['스토리',
#   '연결',
#   '전혀',
#   '안되',
#   '고',
#   '편집',
#   '하',
#   '어서',
#   '끼워맞춘',
#   '드라마',
#   '말아먹',
#   '은',
#   '작품'],
#  ['여자', '주인공', '이', '예쁘', '어서', '끝', '까지', '보', '아다'],
#  ['지구',
#   '를',
#   '지켜라혹',
#   '이',
#   '작품',
#   '을',
#   '보',
#   '고',
#   '만들',
#   'ㄴ',
#   '거',
#   '은',
#   '아니',
#   'ㄴ지'],
#  ['저렇',
#   '게',
#   '힘들',
#   '게',
#   '영화',
#   '를',
#   '만들',
#   'ㄴ데',
#   '왜',
#   '한국영화',
#   '는',
#   '다',
#   '쓰레기',
#   '이',
#   '냐'],
#  ['케릭터',
#   '가',
#   '살',
#   '아',
#   '있',
#   '었으며',
#   '미장센',
#   '이',
#   '훌륭',
#   '하',
#   '었다',
#   '이야기',
#   '는',
#   '몰입',
#   '도',
#   '있',
#   '었고',
#   '불필요한',
#   '샷',
#   '은',
#   '존재',
#   '하',
#   '지',
#   '않',
#   '아다',
#   '노인',
#   '을',
#   '위한나라',
#   '는',
#   '없',
#   '다',
#   '먼저',
#   '보',
#   '아지만',
#   '코엔감독',
#   '매력적인영화',
#   '를',
#   '만들',
#   '는',
#   '멋있',
#   '는',
#   '사람'],
#  ['마지막', '이', '좀황당했지만', '좋은영화'],
#  ['우연히',
#   'tv',
#   '를',
#   '돌리',
#   '어',
#   '보',
#   '다가',
#   '사로잡히',
#   '었다',
#   '최근',
#   '10년',
#   '간',
#   '보',
#   'ㄴ',
#   '코미디',
#   '영화',
#   '중',
#   '최고'],
#  ['열', 'ㄴ', '기', '굿', '화이팅해요누', '나'],
#  ['마이클베',
#   '이',
#   '최근작',
#   '을',
#   '보',
#   'ㄹ',
#   '때',
#   '마다',
#   '느끼',
#   'ㄴ다',
#   '블록버스터',
#   '액션장르',
#   '이',
#   '라',
#   '도',
#   '탄탄',
#   '하',
#   'ㄴ',
#   '시나리오',
#   '는',
#   '영화',
#   '의',
#   '필수라는것',
#   '을',
#   '그리고',
#   '당신',
#   '이',
#   '기대',
#   '어',
#   '하',
#   '던',
#   '메간폭스',
#   '는',
#   '늙',
#   '었다'],
#  ['0점은없나1점', '은', '너무', '후하', '네'],
#  ['미달',
#   '이',
#   '는',
#   '연예계',
#   '를',
#   '바라',
#   '아',
#   '보',
#   '는',
#   '태도',
#   '를',
#   '고치',
#   '어야',
#   '하',
#   'ㄴ다'],
#  ['파괴', '되', 'ㄴ', '관객들'],
#  ['알콜중독자들', '덕', '에', '평점', '이', '낮', '은가'],
#  ['중견배우들',
#   '이',
#   '만들',
#   '어',
#   '놓',
#   '은',
#   '긴장감',
#   '이',
#   '나름',
#   '긴장감',
#   '있',
#   '게',
#   '싸우',
#   '어',
#   '보',
#   '려',
#   '하',
#   '었던',
#   '도술사들',
#   '에',
#   '의하',
#   '어',
#   '헛웃음나온다'],
#  ['남자',
#   '주인공',
#   '늑대',
#   '인간',
#   '으로',
#   '변하',
#   '고',
#   '끝나네유',
#   '평점',
#   '보',
#   '고',
#   '안',
#   '보',
#   'ㄹ까',
#   '하',
#   '다가',
#   '봤는디',
#   '재밌네유',
#   'CG',
#   '보다',
#   '이런',
#   '실물',
#   '특수',
#   '효과',
#   '가',
#   '더',
#   '보',
#   '는',
#   '재미',
#   '가',
#   '있어유',
#   '웃',
#   '기',
#   '이',
#   '기',
#   '까지',
#   '하네유',
#   '근디',
#   '제목',
#   '번역',
#   '은',
#   '어느',
#   '바보',
#   '가',
#   '한거',
#   '이',
#   '어',
#   '그냥',
#   '늑대',
#   '인간',
#   '이',
#   '아니잖여'],
#  ...]

# %% [markdown]
# ### - 7.2 train_docs 의 토큰 결합

# %%
train_docs = [' '.join(doc) for doc in train_docs]

# %%
train_docs[0]
# Out:
# '아 더빙 진짜 짜증나 네 요 목소리'

# %% [markdown]
# ### - 7.3 test_docs 의 토큰 결합

# %%
test_docs = [' '.join(doc) for doc in test_docs]

# %%
test_docs[0]
# Out:
# '굳 ㅋ'

# %% [markdown]
# ### - 7.4 Term-Document Matrix 생성 (train_x)

# %%
train_x = vectorizer.fit_transform(train_docs)

# %% [markdown]
# ### - 7.5 Term-Document Matrix 생성 (test_x)

# %%
test_x = vectorizer.transform(test_docs)

# %% [markdown]
# ### - 7.6 train_y와 test_y 생성

# %%
train_y = whole_data.sentiment.values.tolist()[:len(train_data)]
test_y = whole_data.sentiment.values.tolist()[-len(test_data):]

# %% [markdown]
# ## 8. 분류 모델 생성 및 분류 성능 구하기

# %% [markdown]
# ### - 8.1.1 SVM rbf 모델 생성 및 예측

# %%
classifier_rbf = svm.SVC()
classifier_rbf.fit(train_x, train_y)
prediction_rbf = classifier_rbf.predict(test_x)

print(accuracy_score(test_y, prediction_rbf))
# Out:
# C:\Users\jiyoon\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.47285714285714286

# %% [markdown]
# ### - 8.2.1 SVM linear 모델 생성 및 예측

# %%
classifier_linear = svm.SVC(kernel='linear')
classifier_linear.fit(train_x, train_y)
prediction_linear = classifier_linear.predict(test_x)

print(accuracy_score(test_y, prediction_linear))
# Out:
# 0.7271428571428571

# %% [markdown]
# ### - 8.3.1 Random Forest 모델 생성 및 예측

# %%
rf = RandomForestClassifier()
rf.fit(train_x, train_y)
predict_rf = rf.predict(test_x)

print(accuracy_score(test_y, predict_rf))
# Out:
# C:\Users\jiyoon\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.7571428571428571

# %% [markdown]
# ### - 8.4.1 Gradient Boosting 분류 모델 생성 및 예측

# %%
gb = GradientBoostingClassifier()
gb.fit(train_x, train_y)
predict_gb = gb.predict(test_x)

print(accuracy_score(test_y, predict_gb))
# Out:
# 0.6428571428571429

# %% [markdown]
# # Term-Document Matrix
#
# #### - SVM rbf                         : 0.48
# #### - SVM linear                    : 0.72
# #### - Random Forest            : 0.74
# #### - Gradient Boosting       : 0.64

# %% [markdown]
# ## 7. TF-IDF Matrix

# %%
vectorizer = TfidfVectorizer(min_df = 5,
                             max_df = 0.8,
                             sublinear_tf = True,
                             use_idf = True)
vectorizer
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.8, max_features=None, min_df=5,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=True,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
train_docs = whole_data.reviews.values.tolist()[:len(train_data)]
test_docs  = whole_data.reviews.values.tolist()[-len(test_data):]

# %%
train_docs = [' '.join(doc) for doc in train_docs]
test_docs = [' '.join(doc) for doc in test_docs]

# %%
train_x = vectorizer.fit_transform(train_docs)
test_x = vectorizer.transform(test_docs)

# %%
classifier_rbf = svm.SVC()
classifier_rbf.fit(train_x, train_y)
prediction_rbf = classifier_rbf.predict(test_x)

print(accuracy_score(test_y, prediction_rbf))
# Out:
# C:\Users\jiyoon\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.47285714285714286

# %%
classifier_linear = svm.SVC(kernel='linear')
classifier_linear.fit(train_x, train_y)
prediction_linear = classifier_linear.predict(test_x)

print(accuracy_score(test_y, prediction_linear))
# Out:
# 0.7314285714285714

# %%
rf = RandomForestClassifier()
rf.fit(train_x, train_y)
predict_rf = rf.predict(test_x)

print(accuracy_score(test_y, predict_rf))
# Out:
# C:\Users\jiyoon\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.6985714285714286

# %%
gb = GradientBoostingClassifier()
gb.fit(train_x, train_y)
predict_gb = gb.predict(test_x)

print(accuracy_score(test_y, predict_gb))
# Out:
# 0.6385714285714286

# %% [markdown]
# # TF-IDF Matrix
#
# #### - SVM rbf                         : 0.47
# #### - SVM linear                    : 0.73
# #### - Random Forest            : 0.69
# #### - Gradient Boosting       : 0.64
